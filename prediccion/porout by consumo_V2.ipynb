# %% [markdown]
# # POROUT BY CONSUMO
# * Consumo

# %% [markdown]
# ## Proximos pasos
# * terminar grupos std, avg y trend
# * convertir trend (y std, pensar) en categoricas
# * eliminar columnas base
# * seguir con cluster
# * comparaciones respecto al porout, tablas de proporciones

# %%
import pandas as pd
import numpy as np
import gc
from datetime import datetime
from itertools import compress
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
np.set_printoptions(suppress=True)

# %%
#path_data = ''
#file= f'GAAVANZADA.TBL_PORTOUT_PREPAGO_202107.csv'
df07 = pd.read_csv(f'GAAVANZADA.TBL_PORTOUT_PREPAGO_202107.csv', sep='|', decimal='.')
df06 = pd.read_csv(f'GAAVANZADA.TBL_PORTOUT_PREPAGO_202106.csv', sep='|', decimal='.')
df05 = pd.read_csv(f'GAAVANZADA.TBL_PORTOUT_PREPAGO_202105.csv', sep='|', decimal='.')
# Out:
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (2,5,63,67,70) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (2,5,67) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (2,67,70) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df07['file']='df07'
df06['file']='df06'
df05['file']='df05'

# %%
print(len(df07))
print(len(df06))
print(len(df05))
# Out:
# 3111611
# 3101845
# 3091322

# %%
df=df05
df=df.append(df06)
df=df.append(df07)

# %%
del df05
del df06
del df07
gc.collect()
# Out:
# 15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9304778 entries, 0 to 3111610
# Data columns (total 80 columns):
#  #   Column                                Dtype
# ---  ------                                -----
#  0   CO_ID                                 int64
#  1   CUSTOMER_ID                           int64
#  2   CUSTCODE                              object
#  3   TELE_NUMB                             int64
#  4   TELE_NUMB_COMPLETO                    int64
#  5   IDENTIFICACION                        object
#  6   FECHA_ACTIVACION_BSCS                 object
#  7   POROUT                                int64
#  8   REGION_SIT                            object
#  9   MUNICIPIO_SIT                         object
#  10  DEPTO_SIT                             object
#  11  REGION_SIT_NOCHE                      object
#  12  MUNICIPIO_SIT_NOCHE                   object
#  13  DEPTO_SIT_NOCHE                       object
#  14  REGION_SIT_M1                         object
#  15  MUNICIPIO_SIT_M1                      object
#  16  DEPTO_SIT_M1                          object
#  17  REGION_SIT_NOCHE_M1                   object
#  18  MUNICIPIO_SIT_NOCHE_M1                object
#  19  DEPTO_SIT_NOCHE_M1                    object
#  20  PROM_SEGUNDOS_MA                      float64
#  21  PROM_SEGUNDOS_M1                      float64
#  22  PROM_SEGUNDOS_M2                      float64
#  23  PROM_SEGUNDOS_M3                      float64
#  24  PROM_SEGUNDOS_M4                      float64
#  25  PROM_DATOS_MA                         float64
#  26  PROM_DATOS_M1                         float64
#  27  PROM_DATOS_M2                         float64
#  28  PROM_DATOS_M3                         float64
#  29  PROM_DATOS_M4                         float64
#  30  CANT_SMS_MA                           float64
#  31  CANT_SMS_M1                           float64
#  32  CANT_SMS_M2                           float64
#  33  CANT_SMS_M3                           float64
#  34  CANT_SMS_M4                           float64
#  35  TOTAL_MB_WHATSAPP                     float64
#  36  TOTAL_MB_TWITTER_Y_FACEBOOK           float64
#  37  TOTAL_MB_SNAPCHAT                     float64
#  38  TOTAL_MB_INSTAGRAM                    float64
#  39  TOTAL_MB_WAZE                         float64
#  40  TOTAL_MB_YOUTUBE                      float64
#  41  TOTAL_MB_SPOTIFY                      float64
#  42  TOTAL_MB_GOOGLE_MAPS                  float64
#  43  CONSUMO_TOTAL_MB                      float64
#  44  CANT_PAQ_MAS_COMPRADO_MES             float64
#  45  VLR_PAQ_MAS_COMPRADO_MES              float64
#  46  NOMBRE_PAQ_MAS_COMPRADO_MES           object
#  47  PROMEDIO_SALDO_MES                    float64
#  48  PROMEDIO_SALDO_M1                     float64
#  49  PROMEDIO_SALDO_M2                     float64
#  50  ANTIGUEDAD_USUARIO                    float64
#  51  TOTAL_VALOR_DE_ADELANTA_SALDO         float64
#  52  ES_SMARTPHONE                         float64
#  53  CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR    float64
#  54  VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR     float64
#  55  NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR  object
#  56  RAZON1_MA                             object
#  57  RAZON2_MA                             float64
#  58  RAZON3_MA                             float64
#  59  RAZON1_M1                             object
#  60  RAZON2_M1                             float64
#  61  RAZON3_M1                             float64
#  62  RAZON1_M2                             float64
#  63  RAZON2_M2                             object
#  64  RAZON3_M2                             float64
#  65  RAZON1_M3                             float64
#  66  RAZON2_M3                             float64
#  67  RAZON3_M3                             object
#  68  RAZON1_M4                             float64
#  69  RAZON2_M4                             float64
#  70  RAZON3_M4                             object
#  71  DESACTIVACION_PORTACION_M1            int64
#  72  DESACTIVACION_PORTACION_M2            int64
#  73  DESACTIVACION_PORTACION_M3            int64
#  74  DESACTIVACION_PORTACION_M4            int64
#  75  ACTIVACION_PORTACION_M1               int64
#  76  ACTIVACION_PORTACION_M2               int64
#  77  ACTIVACION_PORTACION_M3               int64
#  78  ACTIVACION_PORTACION_M4               int64
#  79  file                                  object
# dtypes: float64(44), int64(13), object(23)
# memory usage: 5.6+ GB

# %%
df.describe().T
# Out:
#                                          count             mean  \
# CO_ID                              9304778.000    302450781.898
# CUSTOMER_ID                        9304778.000    311718146.609
# TELE_NUMB                          9304778.000   3167513304.808
# TELE_NUMB_COMPLETO                 9304778.000 573051237881.578
# POROUT                             9304778.000            0.033
# PROM_SEGUNDOS_MA                   4080708.000          303.242
# PROM_SEGUNDOS_M1                   4040402.000          307.539
# PROM_SEGUNDOS_M2                   4047358.000          306.863
# PROM_SEGUNDOS_M3                   4043793.000          307.486
# PROM_SEGUNDOS_M4                   2980213.000          316.697
# PROM_DATOS_MA                      3621576.000      4937321.001
# PROM_DATOS_M1                      3566261.000      4665021.394
# PROM_DATOS_M2                      3549224.000      4542119.773
# PROM_DATOS_M3                      2035738.000      4360786.559
# PROM_DATOS_M4                      1023353.000      4337932.634
# CANT_SMS_MA                              0.000              NaN
# CANT_SMS_M1                              0.000              NaN
# CANT_SMS_M2                              0.000              NaN
# CANT_SMS_M3                              0.000              NaN
# CANT_SMS_M4                              0.000              NaN
# TOTAL_MB_WHATSAPP                  2651013.000          557.682
# TOTAL_MB_TWITTER_Y_FACEBOOK        2651013.000         1947.999
# TOTAL_MB_SNAPCHAT                  2651013.000           21.028
# TOTAL_MB_INSTAGRAM                 2651013.000           40.916
# TOTAL_MB_WAZE                      2651013.000            0.000
# TOTAL_MB_YOUTUBE                   2651013.000          259.900
# TOTAL_MB_SPOTIFY                   2651013.000            0.000
# TOTAL_MB_GOOGLE_MAPS               2651013.000            6.531
# CONSUMO_TOTAL_MB                   2651013.000         3780.171
# CANT_PAQ_MAS_COMPRADO_MES           701499.000            2.312
# VLR_PAQ_MAS_COMPRADO_MES            701499.000        -3501.304
# PROMEDIO_SALDO_MES                 3758224.000          932.030
# PROMEDIO_SALDO_M1                  3645878.000          915.998
# PROMEDIO_SALDO_M2                  3659832.000          924.695
# ANTIGUEDAD_USUARIO                 3690418.000          676.792
# TOTAL_VALOR_DE_ADELANTA_SALDO      2958568.000           52.943
# ES_SMARTPHONE                      3758224.000            0.705
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR  609310.000            2.085
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR   609310.000        -3451.798
# RAZON2_MA                                0.000              NaN
# RAZON3_MA                                0.000              NaN
# RAZON2_M1                                0.000              NaN
# RAZON3_M1                                0.000              NaN
# RAZON1_M2                                0.000              NaN
# RAZON3_M2                                0.000              NaN
# RAZON1_M3                                0.000              NaN
# RAZON2_M3                                0.000              NaN
# RAZON1_M4                                0.000              NaN
# RAZON2_M4                                0.000              NaN
# DESACTIVACION_PORTACION_M1         9304778.000            0.000
# DESACTIVACION_PORTACION_M2         9304778.000            0.000
# DESACTIVACION_PORTACION_M3         9304778.000            0.000
# DESACTIVACION_PORTACION_M4         9304778.000            0.000
# ACTIVACION_PORTACION_M1            9304778.000            0.000
# ACTIVACION_PORTACION_M2            9304778.000            0.001
# ACTIVACION_PORTACION_M3            9304778.000            0.001
# ACTIVACION_PORTACION_M4            9304778.000            0.001
#
#                                               std             min  \
# CO_ID                                53892599.282     2794121.000
# CUSTOMER_ID                          54598731.195      478847.000
# TELE_NUMB                            67581061.036   455025681.000
# TELE_NUMB_COMPLETO                 7762776260.372 57455025681.000
# POROUT                                      0.178           0.000
# PROM_SEGUNDOS_MA                          322.627           0.000
# PROM_SEGUNDOS_M1                          327.997           0.000
# PROM_SEGUNDOS_M2                          329.147           0.000
# PROM_SEGUNDOS_M3                          329.710           0.000
# PROM_SEGUNDOS_M4                          331.585           0.000
# PROM_DATOS_MA                        10341046.091           0.000
# PROM_DATOS_M1                        10284758.965           0.000
# PROM_DATOS_M2                        10378684.321           0.000
# PROM_DATOS_M3                        10509583.435           0.000
# PROM_DATOS_M4                        10683473.798           0.000
# CANT_SMS_MA                                   NaN             NaN
# CANT_SMS_M1                                   NaN             NaN
# CANT_SMS_M2                                   NaN             NaN
# CANT_SMS_M3                                   NaN             NaN
# CANT_SMS_M4                                   NaN             NaN
# TOTAL_MB_WHATSAPP                        1402.902           0.000
# TOTAL_MB_TWITTER_Y_FACEBOOK              4972.525           0.000
# TOTAL_MB_SNAPCHAT                          94.630           0.000
# TOTAL_MB_INSTAGRAM                        295.465           0.000
# TOTAL_MB_WAZE                               0.000           0.000
# TOTAL_MB_YOUTUBE                          737.683           0.000
# TOTAL_MB_SPOTIFY                            0.000           0.000
# TOTAL_MB_GOOGLE_MAPS                       77.701           0.000
# CONSUMO_TOTAL_MB                         7448.985           0.000
# CANT_PAQ_MAS_COMPRADO_MES                   2.872           1.000
# VLR_PAQ_MAS_COMPRADO_MES                 4451.482     -643500.000
# PROMEDIO_SALDO_MES                       6117.226           0.000
# PROMEDIO_SALDO_M1                        6194.154           0.000
# PROMEDIO_SALDO_M2                        6214.044           0.000
# ANTIGUEDAD_USUARIO                        753.246          -1.000
# TOTAL_VALOR_DE_ADELANTA_SALDO             464.677           0.000
# ES_SMARTPHONE                               0.456           0.000
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR          2.448           1.000
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR        4609.040     -514800.000
# RAZON2_MA                                     NaN             NaN
# RAZON3_MA                                     NaN             NaN
# RAZON2_M1                                     NaN             NaN
# RAZON3_M1                                     NaN             NaN
# RAZON1_M2                                     NaN             NaN
# RAZON3_M2                                     NaN             NaN
# RAZON1_M3                                     NaN             NaN
# RAZON2_M3                                     NaN             NaN
# RAZON1_M4                                     NaN             NaN
# RAZON2_M4                                     NaN             NaN
# DESACTIVACION_PORTACION_M1                  0.003           0.000
# DESACTIVACION_PORTACION_M2                  0.005           0.000
# DESACTIVACION_PORTACION_M3                  0.005           0.000
# DESACTIVACION_PORTACION_M4                  0.003           0.000
# ACTIVACION_PORTACION_M1                     0.020           0.000
# ACTIVACION_PORTACION_M2                     0.035           0.000
# ACTIVACION_PORTACION_M3                     0.035           0.000
# ACTIVACION_PORTACION_M4                     0.030           0.000
#
#                                                 25%              50%  \
# CO_ID                                 280525794.250    324228968.500
# CUSTOMER_ID                           290008923.250    333737501.500
# TELE_NUMB                            3124090186.500   3145285759.000
# TELE_NUMB_COMPLETO                 573124090186.500 573145285759.000
# POROUT                                        0.000            0.000
# PROM_SEGUNDOS_MA                            104.886          212.500
# PROM_SEGUNDOS_M1                            105.625          215.065
# PROM_SEGUNDOS_M2                            105.964          214.550
# PROM_SEGUNDOS_M3                            105.667          214.240
# PROM_SEGUNDOS_M4                            112.840          224.316
# PROM_DATOS_MA                              4707.969       697395.717
# PROM_DATOS_M1                              4034.595       591403.736
# PROM_DATOS_M2                              4381.934       609076.651
# PROM_DATOS_M3                              2609.565       429014.817
# PROM_DATOS_M4                              3217.500       475346.013
# CANT_SMS_MA                                     NaN              NaN
# CANT_SMS_M1                                     NaN              NaN
# CANT_SMS_M2                                     NaN              NaN
# CANT_SMS_M3                                     NaN              NaN
# CANT_SMS_M4                                     NaN              NaN
# TOTAL_MB_WHATSAPP                             0.000           75.000
# TOTAL_MB_TWITTER_Y_FACEBOOK                   0.000          144.000
# TOTAL_MB_SNAPCHAT                             0.000            0.000
# TOTAL_MB_INSTAGRAM                            0.000            0.000
# TOTAL_MB_WAZE                                 0.000            0.000
# TOTAL_MB_YOUTUBE                              0.000           21.000
# TOTAL_MB_SPOTIFY                              0.000            0.000
# TOTAL_MB_GOOGLE_MAPS                          0.000            0.000
# CONSUMO_TOTAL_MB                             19.000          740.000
# CANT_PAQ_MAS_COMPRADO_MES                     1.000            1.000
# VLR_PAQ_MAS_COMPRADO_MES                  -4000.000        -2000.000
# PROMEDIO_SALDO_MES                            0.000            3.890
# PROMEDIO_SALDO_M1                             0.000            3.480
# PROMEDIO_SALDO_M2                             0.000            3.420
# ANTIGUEDAD_USUARIO                          115.000          494.000
# TOTAL_VALOR_DE_ADELANTA_SALDO                 0.000            0.000
# ES_SMARTPHONE                                 0.000            1.000
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR            1.000            1.000
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR         -4000.000        -2000.000
# RAZON2_MA                                       NaN              NaN
# RAZON3_MA                                       NaN              NaN
# RAZON2_M1                                       NaN              NaN
# RAZON3_M1                                       NaN              NaN
# RAZON1_M2                                       NaN              NaN
# RAZON3_M2                                       NaN              NaN
# RAZON1_M3                                       NaN              NaN
# RAZON2_M3                                       NaN              NaN
# RAZON1_M4                                       NaN              NaN
# RAZON2_M4                                       NaN              NaN
# DESACTIVACION_PORTACION_M1                    0.000            0.000
# DESACTIVACION_PORTACION_M2                    0.000            0.000
# DESACTIVACION_PORTACION_M3                    0.000            0.000
# DESACTIVACION_PORTACION_M4                    0.000            0.000
# ACTIVACION_PORTACION_M1                       0.000            0.000
# ACTIVACION_PORTACION_M2                       0.000            0.000
# ACTIVACION_PORTACION_M3                       0.000            0.000
# ACTIVACION_PORTACION_M4                       0.000            0.000
#
#                                                 75%              max
# CO_ID                                 339973052.250    352353868.000
# CUSTOMER_ID                           349490263.250    361878975.000
# TELE_NUMB                            3216902983.500   3508997887.000
# TELE_NUMB_COMPLETO                 573216902983.500 573508997887.000
# POROUT                                        0.000            1.000
# PROM_SEGUNDOS_MA                            393.012        36231.500
# PROM_SEGUNDOS_M1                            398.593        30830.300
# PROM_SEGUNDOS_M2                            396.750        49784.526
# PROM_SEGUNDOS_M3                            397.106        34042.000
# PROM_SEGUNDOS_M4                            409.687        29007.235
# PROM_DATOS_MA                           5335809.131   1224774348.704
# PROM_DATOS_M1                           4751644.062   1405229628.184
# PROM_DATOS_M2                           4438844.469   1274810598.977
# PROM_DATOS_M3                           3976704.009   1528717489.825
# PROM_DATOS_M4                           3896141.699   1187491587.325
# CANT_SMS_MA                                     NaN              NaN
# CANT_SMS_M1                                     NaN              NaN
# CANT_SMS_M2                                     NaN              NaN
# CANT_SMS_M3                                     NaN              NaN
# CANT_SMS_M4                                     NaN              NaN
# TOTAL_MB_WHATSAPP                           494.000       137910.000
# TOTAL_MB_TWITTER_Y_FACEBOOK                1506.000       514097.000
# TOTAL_MB_SNAPCHAT                             5.000         5071.000
# TOTAL_MB_INSTAGRAM                            1.000        60404.000
# TOTAL_MB_WAZE                                 0.000            0.000
# TOTAL_MB_YOUTUBE                            174.000        56201.000
# TOTAL_MB_SPOTIFY                              0.000            0.000
# TOTAL_MB_GOOGLE_MAPS                          0.000        12895.000
# CONSUMO_TOTAL_MB                           4081.000       545473.000
# CANT_PAQ_MAS_COMPRADO_MES                     2.000           31.000
# VLR_PAQ_MAS_COMPRADO_MES                  -1000.000            0.000
# PROMEDIO_SALDO_MES                          633.333      2695932.868
# PROMEDIO_SALDO_M1                           568.433      2702990.070
# PROMEDIO_SALDO_M2                           587.097      2693630.514
# ANTIGUEDAD_USUARIO                          975.000         6576.000
# TOTAL_VALOR_DE_ADELANTA_SALDO                 0.000       145000.000
# ES_SMARTPHONE                                 1.000            1.000
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR            2.000           39.000
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR         -1500.000            0.000
# RAZON2_MA                                       NaN              NaN
# RAZON3_MA                                       NaN              NaN
# RAZON2_M1                                       NaN              NaN
# RAZON3_M1                                       NaN              NaN
# RAZON1_M2                                       NaN              NaN
# RAZON3_M2                                       NaN              NaN
# RAZON1_M3                                       NaN              NaN
# RAZON2_M3                                       NaN              NaN
# RAZON1_M4                                       NaN              NaN
# RAZON2_M4                                       NaN              NaN
# DESACTIVACION_PORTACION_M1                    0.000            1.000
# DESACTIVACION_PORTACION_M2                    0.000            1.000
# DESACTIVACION_PORTACION_M3                    0.000            1.000
# DESACTIVACION_PORTACION_M4                    0.000            1.000
# ACTIVACION_PORTACION_M1                       0.000            1.000
# ACTIVACION_PORTACION_M2                       0.000            1.000
# ACTIVACION_PORTACION_M3                       0.000            1.000
# ACTIVACION_PORTACION_M4                       0.000            1.000

# %%
len(df)
# Out:
# 9304778

# %%
def tipoDocumento(dni):    
    #text='9005514169.0'
    pos=dni.find('.')
    if pos != -1:
        dni=dni[0:pos]    
    longitud=len(dni)
    inicial=dni[0]
    respuesta="desconocido"
    if (longitud == 9 or longitud==10) and (inicial=='9' or inicial=='8'):
        respuesta="NIT"
    elif (longitud == 7 or longitud==8):
        respuesta="cedula"
    elif (longitud == 10) and (inicial=='1'):
        respuesta="cedula"
    elif longitud<=6:
        respuesta="sin id"
    return respuesta

# %%
#tipoDocumento('9005514169.0')

# %%
###  contar nullos en identificacion
df['IDENTIFICACION'].isnull().sum()
# Out:
# 5

# %%
df['IDENTIFICACION'].fillna(0, inplace=True)

# %%
df['IDENTIFICACION']=df[['IDENTIFICACION']].applymap(str)

# %% [markdown]
# #### Próximos pasos
# * descartar columnas sin información

# %%
df['tipo_id']=df['IDENTIFICACION'].apply(tipoDocumento)

# %%
len(df)
# Out:
# 9304778

# %%
df['tipo_id'].value_counts()
# Out:
# NIT            8260485
# cedula          950408
# sin id           65334
# desconocido      28551
# Name: tipo_id, dtype: int64

# %%
df[df['tipo_id']=='desconocido'].sample(20)
# Out:
#              CO_ID  CUSTOMER_ID     CUSTCODE   TELE_NUMB  TELE_NUMB_COMPLETO  \
# 1356281  156781604    162114625        2.754  3126264681        573126264681
# 1261893  263802068    273265901        2.182  3118700256        573118700256
# 1557478  270755595    280231119        2.188  3124914251        573124914251
# 2358323  244773008    254193634  2.165236416  3223412185        573223412185
# 1570964  293636530    303128678  2.208440616  3112958632        573112958632
# 2263664  277946970    287428094  2.194686167  3112672862        573112672862
# 889852   268326459    277799765  2.186133670  3208383027        573208383027
# 1177372  282858281    292343054  2.199025944  3117634746        573117634746
# 317802   332216955    341729846  2.242834474  3102043214        573102043214
# 1652147  248506922    257933838  2.168543851  3212402903        573212402903
# 1270575  273386373    282863990  2.190652005  3209177486        573209177486
# 1145057  290111823    299601620  2.205352308  3118577369        573118577369
# 2716152  270576553    280051929        2.188  3122405348        573122405348
# 1978030  271226249    280702229  2.188715400  3136241426        573136241426
# 1849130   17751748     22943872   1.36019872  3103379870        573103379870
# 614298   318609404    328115154  2.230850527  3204178779        573204178779
# 2749805  286294371    295781806  2.201990307  3133172216        573133172216
# 1744219  287555954    297044125  2.203101393  3106730176        573106730176
# 1109465  274693160    284171749  2.191777264  3134156181        573134156181
# 1973193  269479176    278953598  2.187173447  3114838083        573114838083
#
#           IDENTIFICACION  FECHA_ACTIVACION_BSCS  POROUT    REGION_SIT  \
# 1356281     811021219878  2014-05-17 18:55:52.0       0           NaN
# 1261893        777777777  2018-08-14 18:48:05.0       0  SurOccidente
# 1557478       934511121  2018-11-14 13:51:38.0       0       Oriente
# 2358323        777777777  2017-11-07 10:45:49.0       0  NorOccidente
# 1570964        777777777  2019-09-17 10:15:08.0       0       Oriente
# 2263664        777777777  2019-02-19 12:36:08.0       0        Centro
# 889852        934511121  2018-10-11 12:51:18.0       0       Oriente
# 1177372        777777777  2019-04-27 19:54:02.0       0        Centro
# 317802         777777777  2020-12-02 12:15:47.0       0           NaN
# 1652147        777777777  2018-01-04 11:45:50.0       0        Centro
# 1270575        777777777  2018-12-17 18:12:03.0       0           NaN
# 1145057        777777777  2019-08-01 11:30:13.0       0           NaN
# 2716152        777777777  2018-11-11 18:12:02.0       0           NaN
# 1978030        777777777  2018-11-21 16:15:14.0       0  NorOccidente
# 1849130       3103379870  2005-06-30 00:00:00.0       1        Centro
# 614298   716343207091983  2020-07-08 21:25:12.0       1  SurOccidente
# 2749805        777777777  2019-06-16 14:57:04.0       0           NaN
# 1744219        777777777  2019-07-02 16:00:09.0       0           NaN
# 1109465        777777777  2019-01-08 15:51:03.0       0        Centro
# 1973193       741805941  2018-10-26 08:31:42.0       0           NaN
#
#         MUNICIPIO_SIT     DEPTO_SIT REGION_SIT_NOCHE MUNICIPIO_SIT_NOCHE  \
# 1356281           NaN           NaN              NaN                 NaN
# 1261893         Neiva         Huila     SurOccidente               Neiva
# 1557478       Granada          Meta          Oriente             Granada
# 2358323        Quibdo         Choco     NorOccidente              Quibdo
# 1570964         Nobsa        Boyaca          Oriente               Nobsa
# 2263664        Soacha  Cundinamarca           Centro              Soacha
# 889852      Sutatausa  Cundinamarca          Oriente           Sutatausa
# 1177372    Bogota D C  Cundinamarca           Centro          Bogota D C
# 317802            NaN           NaN              NaN                 NaN
# 1652147    Bogota D C  Cundinamarca           Centro          Bogota D C
# 1270575           NaN           NaN              NaN                 NaN
# 1145057           NaN           NaN              NaN                 NaN
# 2716152           NaN           NaN              NaN                 NaN
# 1978030         Bello     Antioquia     NorOccidente               Bello
# 1849130    Bogota D C  Cundinamarca           Centro          Bogota D C
# 614298         Ibague        Tolima     SurOccidente              Ibague
# 2749805           NaN           NaN              NaN                 NaN
# 1744219           NaN           NaN              NaN                 NaN
# 1109465    Bogota D C  Cundinamarca           Centro          Bogota D C
# 1973193           NaN           NaN              NaN                 NaN
#
#         DEPTO_SIT_NOCHE REGION_SIT_M1 MUNICIPIO_SIT_M1  DEPTO_SIT_M1  \
# 1356281             NaN           NaN              NaN           NaN
# 1261893           Huila  SurOccidente            Neiva         Huila
# 1557478            Meta           NaN              NaN           NaN
# 2358323           Choco  NorOccidente           Quibdo         Choco
# 1570964          Boyaca       Oriente         Busbanza        Boyaca
# 2263664    Cundinamarca        Centro           Soacha  Cundinamarca
# 889852     Cundinamarca       Oriente        Sutatausa  Cundinamarca
# 1177372    Cundinamarca           NaN              NaN           NaN
# 317802              NaN  SurOccidente      El Doncello       Caqueta
# 1652147    Cundinamarca        Centro       Bogota D C  Cundinamarca
# 1270575             NaN           NaN              NaN           NaN
# 1145057             NaN  NorOccidente         Medellin     Antioquia
# 2716152             NaN  SurOccidente            Guamo        Tolima
# 1978030       Antioquia  NorOccidente            Bello     Antioquia
# 1849130    Cundinamarca       Oriente    Villavicencio          Meta
# 614298           Tolima  SurOccidente           Ibague        Tolima
# 2749805             NaN           NaN              NaN           NaN
# 1744219             NaN           NaN              NaN           NaN
# 1109465    Cundinamarca        Centro       Bogota D C  Cundinamarca
# 1973193             NaN           NaN              NaN           NaN
#
#         REGION_SIT_NOCHE_M1 MUNICIPIO_SIT_NOCHE_M1 DEPTO_SIT_NOCHE_M1  \
# 1356281                 NaN                    NaN                NaN
# 1261893        SurOccidente                  Neiva              Huila
# 1557478                 NaN                    NaN                NaN
# 2358323        NorOccidente                 Quibdo              Choco
# 1570964             Oriente               Busbanza             Boyaca
# 2263664              Centro                 Soacha       Cundinamarca
# 889852              Oriente              Sutatausa       Cundinamarca
# 1177372                 NaN                    NaN                NaN
# 317802         SurOccidente            El Doncello            Caqueta
# 1652147              Centro             Bogota D C       Cundinamarca
# 1270575                 NaN                    NaN                NaN
# 1145057        NorOccidente               Medellin          Antioquia
# 2716152        SurOccidente                  Guamo             Tolima
# 1978030        NorOccidente                  Bello          Antioquia
# 1849130             Oriente          Villavicencio               Meta
# 614298         SurOccidente                 Ibague             Tolima
# 2749805                 NaN                    NaN                NaN
# 1744219                 NaN                    NaN                NaN
# 1109465              Centro             Bogota D C       Cundinamarca
# 1973193                 NaN                    NaN                NaN
#
#          PROM_SEGUNDOS_MA  PROM_SEGUNDOS_M1  PROM_SEGUNDOS_M2  \
# 1356281           251.786           302.581           265.975
# 1261893            79.542            97.982            70.196
# 1557478           528.935           583.476           130.615
# 2358323            99.136           215.753           141.300
# 1570964            88.405            99.432           122.974
# 2263664            63.310           147.872           215.449
# 889852            993.574           846.929           679.188
# 1177372           192.088           144.010           241.758
# 317802            638.429            89.643           155.588
# 1652147           249.519           187.629           213.090
# 1270575           105.000               NaN            75.500
# 1145057           193.500           188.300           278.818
# 2716152           114.079           227.409           432.088
# 1978030            37.500            94.286           108.000
# 1849130           301.773           392.874           313.796
# 614298            214.514           103.836           174.657
# 2749805               NaN               NaN               NaN
# 1744219               NaN               NaN               NaN
# 1109465           111.830           148.207           217.167
# 1973193               NaN            24.250            18.667
#
#          PROM_SEGUNDOS_M3  PROM_SEGUNDOS_M4  PROM_DATOS_MA  PROM_DATOS_M1  \
# 1356281           407.231               NaN            NaN            NaN
# 1261893            92.309               NaN     425686.767     250957.813
# 1557478           520.959               NaN       7481.295      11439.600
# 2358323           134.379           178.875      81501.607   17888772.642
# 1570964           110.769           129.971            NaN       3838.917
# 2263664           289.131           145.626         65.000     889613.979
# 889852            504.175           630.480   34423943.064   74176702.693
# 1177372           169.770           208.028      35919.704      31846.315
# 317802            137.267           584.788          0.000         55.959
# 1652147           290.000           245.704            NaN            NaN
# 1270575             1.000             0.000          5.115          1.405
# 1145057           437.867           102.952       8520.056      25041.250
# 2716152           351.172           452.562          4.000        405.214
# 1978030            94.333           316.333         72.038     425098.092
# 1849130           206.360           389.577    1033262.321    1207021.815
# 614298            263.227           128.800   40079290.897   30502033.689
# 2749805               NaN               NaN            NaN            NaN
# 1744219               NaN           512.875            NaN            NaN
# 1109465           269.064           212.597       5065.260     321767.557
# 1973193               NaN            33.000            NaN            NaN
#
#          PROM_DATOS_M2  PROM_DATOS_M3  PROM_DATOS_M4  CANT_SMS_MA  \
# 1356281            NaN            NaN            NaN          NaN
# 1261893     172293.965     371300.953            NaN          NaN
# 1557478      16756.770      28389.960            NaN          NaN
# 2358323     260948.938            NaN            NaN          NaN
# 1570964       3012.912            NaN            NaN          NaN
# 2263664    2347737.310            NaN            NaN          NaN
# 889852   180089637.355            NaN            NaN          NaN
# 1177372     273141.665            NaN            NaN          NaN
# 317802          46.773            NaN            NaN          NaN
# 1652147            NaN            NaN            NaN          NaN
# 1270575         13.726            NaN            NaN          NaN
# 1145057      18168.250            NaN            NaN          NaN
# 2716152   11125695.469         61.900        142.875          NaN
# 1978030       2184.613            NaN            NaN          NaN
# 1849130    2114704.979            NaN            NaN          NaN
# 614298    18095802.414            NaN            NaN          NaN
# 2749805            NaN            NaN            NaN          NaN
# 1744219            NaN            NaN            NaN          NaN
# 1109465    2398481.148            NaN            NaN          NaN
# 1973193            NaN            NaN            NaN          NaN
#
#          CANT_SMS_M1  CANT_SMS_M2  CANT_SMS_M3  CANT_SMS_M4  \
# 1356281          NaN          NaN          NaN          NaN
# 1261893          NaN          NaN          NaN          NaN
# 1557478          NaN          NaN          NaN          NaN
# 2358323          NaN          NaN          NaN          NaN
# 1570964          NaN          NaN          NaN          NaN
# 2263664          NaN          NaN          NaN          NaN
# 889852           NaN          NaN          NaN          NaN
# 1177372          NaN          NaN          NaN          NaN
# 317802           NaN          NaN          NaN          NaN
# 1652147          NaN          NaN          NaN          NaN
# 1270575          NaN          NaN          NaN          NaN
# 1145057          NaN          NaN          NaN          NaN
# 2716152          NaN          NaN          NaN          NaN
# 1978030          NaN          NaN          NaN          NaN
# 1849130          NaN          NaN          NaN          NaN
# 614298           NaN          NaN          NaN          NaN
# 2749805          NaN          NaN          NaN          NaN
# 1744219          NaN          NaN          NaN          NaN
# 1109465          NaN          NaN          NaN          NaN
# 1973193          NaN          NaN          NaN          NaN
#
#          TOTAL_MB_WHATSAPP  TOTAL_MB_TWITTER_Y_FACEBOOK  TOTAL_MB_SNAPCHAT  \
# 1356281                NaN                          NaN                NaN
# 1261893              4.000                      148.000              0.000
# 1557478              0.000                        0.000              0.000
# 2358323              0.000                        0.000              0.000
# 1570964                NaN                          NaN                NaN
# 2263664              0.000                        0.000              0.000
# 889852            6093.000                    11171.000             17.000
# 1177372              0.000                        0.000              0.000
# 317802                 NaN                          NaN                NaN
# 1652147                NaN                          NaN                NaN
# 1270575                NaN                          NaN                NaN
# 1145057                NaN                          NaN                NaN
# 2716152                NaN                          NaN                NaN
# 1978030              0.000                        0.000              0.000
# 1849130            139.000                      172.000              2.000
# 614298            4495.000                     7631.000              5.000
# 2749805                NaN                          NaN                NaN
# 1744219                NaN                          NaN                NaN
# 1109465              0.000                        0.000              0.000
# 1973193                NaN                          NaN                NaN
#
#          TOTAL_MB_INSTAGRAM  TOTAL_MB_WAZE  TOTAL_MB_YOUTUBE  \
# 1356281                 NaN            NaN               NaN
# 1261893               0.000          0.000             7.000
# 1557478               0.000          0.000             0.000
# 2358323               0.000          0.000             0.000
# 1570964                 NaN            NaN               NaN
# 2263664               0.000          0.000             0.000
# 889852                0.000          0.000           188.000
# 1177372               0.000          0.000             0.000
# 317802                  NaN            NaN               NaN
# 1652147                 NaN            NaN               NaN
# 1270575                 NaN            NaN               NaN
# 1145057                 NaN            NaN               NaN
# 2716152                 NaN            NaN               NaN
# 1978030               0.000          0.000             0.000
# 1849130               0.000          0.000           121.000
# 614298               12.000          0.000           125.000
# 2749805                 NaN            NaN               NaN
# 1744219                 NaN            NaN               NaN
# 1109465               0.000          0.000             0.000
# 1973193                 NaN            NaN               NaN
#
#          TOTAL_MB_SPOTIFY  TOTAL_MB_GOOGLE_MAPS  CONSUMO_TOTAL_MB  \
# 1356281               NaN                   NaN               NaN
# 1261893             0.000                 0.000           202.000
# 1557478             0.000                 0.000             1.000
# 2358323             0.000                 0.000            17.000
# 1570964               NaN                   NaN               NaN
# 2263664             0.000                 0.000             0.000
# 889852              0.000                 0.000         19468.000
# 1177372             0.000                 0.000             6.000
# 317802                NaN                   NaN               NaN
# 1652147               NaN                   NaN               NaN
# 1270575               NaN                   NaN               NaN
# 1145057               NaN                   NaN               NaN
# 2716152               NaN                   NaN               NaN
# 1978030             0.000                 0.000             0.000
# 1849130             0.000                 0.000           936.000
# 614298              0.000                 0.000         15977.000
# 2749805               NaN                   NaN               NaN
# 1744219               NaN                   NaN               NaN
# 1109465             0.000                 0.000             1.000
# 1973193               NaN                   NaN               NaN
#
#          CANT_PAQ_MAS_COMPRADO_MES  VLR_PAQ_MAS_COMPRADO_MES  \
# 1356281                        NaN                       NaN
# 1261893                      2.000                 -4000.000
# 1557478                      2.000                 -2000.000
# 2358323                        NaN                       NaN
# 1570964                        NaN                       NaN
# 2263664                        NaN                       NaN
# 889852                       4.000                 -8000.000
# 1177372                        NaN                       NaN
# 317802                         NaN                       NaN
# 1652147                        NaN                       NaN
# 1270575                        NaN                       NaN
# 1145057                        NaN                       NaN
# 2716152                        NaN                       NaN
# 1978030                        NaN                       NaN
# 1849130                        NaN                       NaN
# 614298                       1.000                 -1000.000
# 2749805                        NaN                       NaN
# 1744219                        NaN                       NaN
# 1109465                        NaN                       NaN
# 1973193                        NaN                       NaN
#
#                                NOMBRE_PAQ_MAS_COMPRADO_MES  \
# 1356281                                                NaN
# 1261893  Navegacion 40MB + ChatWhatsapp Facebook Twitte...
# 1557478                         Paquetes Minutos migracion
# 2358323                                                NaN
# 1570964                                                NaN
# 2263664                                                NaN
# 889852   Navegacion 40MB + ChatWhatsapp Facebook Twitte...
# 1177372                                                NaN
# 317802                                                 NaN
# 1652147                                                NaN
# 1270575                                                NaN
# 1145057                                                NaN
# 2716152                                                NaN
# 1978030                                                NaN
# 1849130                                                NaN
# 614298                              Navegacion 50 MB 1 Dia
# 2749805                                                NaN
# 1744219                                                NaN
# 1109465                                                NaN
# 1973193                                                NaN
#
#          PROMEDIO_SALDO_MES  PROMEDIO_SALDO_M1  PROMEDIO_SALDO_M2  \
# 1356281                 NaN                NaN                NaN
# 1261893               0.000              0.000              0.000
# 1557478              63.430                NaN              1.030
# 2358323               3.200              3.200              3.200
# 1570964               3.000            552.600           1078.677
# 2263664             558.669           1428.097            774.927
# 889852                3.100              3.100              3.100
# 1177372            1828.133            677.320           2273.036
# 317802                  NaN              0.000                NaN
# 1652147            2197.165           3760.300           3000.003
# 1270575                 NaN                NaN                NaN
# 1145057                 NaN           3293.733           1553.548
# 2716152                 NaN            132.000            921.032
# 1978030            1759.226           1600.000                NaN
# 1849130               0.000              0.000              0.000
# 614298               53.613              2.000              4.065
# 2749805                 NaN                NaN                NaN
# 1744219                 NaN                NaN           6052.516
# 1109465             671.366            765.383           1155.334
# 1973193                 NaN                NaN                NaN
#
#          ANTIGUEDAD_USUARIO  TOTAL_VALOR_DE_ADELANTA_SALDO  ES_SMARTPHONE  \
# 1356281                 NaN                            NaN            NaN
# 1261893            1051.000                          0.000          1.000
# 1557478             945.000                          0.000          1.000
# 2358323            1299.000                          0.000          1.000
# 1570964             483.000                          0.000          0.000
# 2263664             832.000                        500.000          1.000
# 889852              949.000                          0.000          1.000
# 1177372             765.000                          0.000          1.000
# 317802                  NaN                            NaN            NaN
# 1652147            1243.000                          0.000          0.000
# 1270575                 NaN                            NaN            NaN
# 1145057                 NaN                            NaN            NaN
# 2716152                 NaN                            NaN            NaN
# 1978030             922.000                          0.000          1.000
# 1849130            5813.000                          0.000          1.000
# 614298              253.000                          0.000          1.000
# 2749805                 NaN                            NaN            NaN
# 1744219                 NaN                            NaN            NaN
# 1109465             874.000                          0.000          1.000
# 1973193                 NaN                            NaN            NaN
#
#          CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 1356281                                 NaN
# 1261893                               1.000
# 1557478                                 NaN
# 2358323                               2.000
# 1570964                                 NaN
# 2263664                               1.000
# 889852                               11.000
# 1177372                                 NaN
# 317802                                  NaN
# 1652147                                 NaN
# 1270575                                 NaN
# 1145057                                 NaN
# 2716152                                 NaN
# 1978030                                 NaN
# 1849130                                 NaN
# 614298                                1.000
# 2749805                                 NaN
# 1744219                                 NaN
# 1109465                                 NaN
# 1973193                                 NaN
#
#          VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 1356281                                NaN
# 1261893                          -2000.000
# 1557478                                NaN
# 2358323                          -4000.000
# 1570964                                NaN
# 2263664                          -7000.000
# 889852                          -22000.000
# 1177372                                NaN
# 317802                                 NaN
# 1652147                                NaN
# 1270575                                NaN
# 1145057                                NaN
# 2716152                                NaN
# 1978030                                NaN
# 1849130                                NaN
# 614298                           -2000.000
# 2749805                                NaN
# 1744219                                NaN
# 1109465                                NaN
# 1973193                                NaN
#
#                       NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR RAZON1_MA  \
# 1356281                                                NaN       NaN
# 1261893  Navegacion 40MB + ChatWhatsapp Facebook Twitte...       NaN
# 1557478                                                NaN       NaN
# 2358323  Navegacion 40MB + ChatWhatsapp Facebook Twitte...       NaN
# 1570964                                                NaN       NaN
# 2263664  Todo Incluido Voz y SMS Ilimitados + WTF + 500...       NaN
# 889852   Navegacion 40MB + ChatWhatsapp Facebook Twitte...       NaN
# 1177372                                                NaN       NaN
# 317802                                                 NaN       NaN
# 1652147                                                NaN       NaN
# 1270575                                                NaN       NaN
# 1145057                                                NaN       NaN
# 2716152                                                NaN       NaN
# 1978030                                                NaN       NaN
# 1849130                                                NaN       NaN
# 614298   Navegacion 40MB + ChatWhatsapp Facebook Twitte...       NaN
# 2749805                                                NaN       NaN
# 1744219                                                NaN       NaN
# 1109465                                                NaN       NaN
# 1973193                                                NaN       NaN
#
#          RAZON2_MA  RAZON3_MA RAZON1_M1  RAZON2_M1  RAZON3_M1  RAZON1_M2  \
# 1356281        NaN        NaN       NaN        NaN        NaN        NaN
# 1261893        NaN        NaN       NaN        NaN        NaN        NaN
# 1557478        NaN        NaN       NaN        NaN        NaN        NaN
# 2358323        NaN        NaN       NaN        NaN        NaN        NaN
# 1570964        NaN        NaN       NaN        NaN        NaN        NaN
# 2263664        NaN        NaN       NaN        NaN        NaN        NaN
# 889852         NaN        NaN       NaN        NaN        NaN        NaN
# 1177372        NaN        NaN       NaN        NaN        NaN        NaN
# 317802         NaN        NaN       NaN        NaN        NaN        NaN
# 1652147        NaN        NaN       NaN        NaN        NaN        NaN
# 1270575        NaN        NaN       NaN        NaN        NaN        NaN
# 1145057        NaN        NaN       NaN        NaN        NaN        NaN
# 2716152        NaN        NaN       NaN        NaN        NaN        NaN
# 1978030        NaN        NaN       NaN        NaN        NaN        NaN
# 1849130        NaN        NaN       NaN        NaN        NaN        NaN
# 614298         NaN        NaN       NaN        NaN        NaN        NaN
# 2749805        NaN        NaN       NaN        NaN        NaN        NaN
# 1744219        NaN        NaN       NaN        NaN        NaN        NaN
# 1109465        NaN        NaN       NaN        NaN        NaN        NaN
# 1973193        NaN        NaN       NaN        NaN        NaN        NaN
#
#         RAZON2_M2  RAZON3_M2  RAZON1_M3  RAZON2_M3 RAZON3_M3  RAZON1_M4  \
# 1356281       NaN        NaN        NaN        NaN       NaN        NaN
# 1261893       NaN        NaN        NaN        NaN       NaN        NaN
# 1557478       NaN        NaN        NaN        NaN       NaN        NaN
# 2358323       NaN        NaN        NaN        NaN       NaN        NaN
# 1570964       NaN        NaN        NaN        NaN       NaN        NaN
# 2263664       NaN        NaN        NaN        NaN       NaN        NaN
# 889852        NaN        NaN        NaN        NaN       NaN        NaN
# 1177372       NaN        NaN        NaN        NaN       NaN        NaN
# 317802        NaN        NaN        NaN        NaN       NaN        NaN
# 1652147       NaN        NaN        NaN        NaN       NaN        NaN
# 1270575       NaN        NaN        NaN        NaN       NaN        NaN
# 1145057       NaN        NaN        NaN        NaN       NaN        NaN
# 2716152       NaN        NaN        NaN        NaN       NaN        NaN
# 1978030       NaN        NaN        NaN        NaN       NaN        NaN
# 1849130       NaN        NaN        NaN        NaN       NaN        NaN
# 614298        NaN        NaN        NaN        NaN       NaN        NaN
# 2749805       NaN        NaN        NaN        NaN       NaN        NaN
# 1744219       NaN        NaN        NaN        NaN       NaN        NaN
# 1109465       NaN        NaN        NaN        NaN       NaN        NaN
# 1973193       NaN        NaN        NaN        NaN       NaN        NaN
#
#          RAZON2_M4 RAZON3_M4  DESACTIVACION_PORTACION_M1  \
# 1356281        NaN       NaN                           0
# 1261893        NaN       NaN                           0
# 1557478        NaN       NaN                           0
# 2358323        NaN       NaN                           0
# 1570964        NaN       NaN                           0
# 2263664        NaN       NaN                           0
# 889852         NaN       NaN                           0
# 1177372        NaN       NaN                           0
# 317802         NaN       NaN                           0
# 1652147        NaN       NaN                           0
# 1270575        NaN       NaN                           0
# 1145057        NaN       NaN                           0
# 2716152        NaN       NaN                           0
# 1978030        NaN       NaN                           0
# 1849130        NaN       NaN                           0
# 614298         NaN       NaN                           0
# 2749805        NaN       NaN                           0
# 1744219        NaN       NaN                           0
# 1109465        NaN       NaN                           0
# 1973193        NaN       NaN                           0
#
#          DESACTIVACION_PORTACION_M2  DESACTIVACION_PORTACION_M3  \
# 1356281                           0                           0
# 1261893                           0                           0
# 1557478                           0                           0
# 2358323                           0                           0
# 1570964                           0                           0
# 2263664                           0                           0
# 889852                            0                           0
# 1177372                           0                           0
# 317802                            0                           0
# 1652147                           0                           0
# 1270575                           0                           0
# 1145057                           0                           0
# 2716152                           0                           0
# 1978030                           0                           0
# 1849130                           0                           0
# 614298                            0                           0
# 2749805                           0                           0
# 1744219                           0                           0
# 1109465                           0                           0
# 1973193                           0                           0
#
#          DESACTIVACION_PORTACION_M4  ACTIVACION_PORTACION_M1  \
# 1356281                           0                        0
# 1261893                           0                        0
# 1557478                           0                        0
# 2358323                           0                        0
# 1570964                           0                        0
# 2263664                           0                        0
# 889852                            0                        0
# 1177372                           0                        0
# 317802                            0                        0
# 1652147                           0                        0
# 1270575                           0                        0
# 1145057                           0                        0
# 2716152                           0                        0
# 1978030                           0                        0
# 1849130                           0                        0
# 614298                            0                        0
# 2749805                           0                        0
# 1744219                           0                        0
# 1109465                           0                        0
# 1973193                           0                        0
#
#          ACTIVACION_PORTACION_M2  ACTIVACION_PORTACION_M3  \
# 1356281                        0                        0
# 1261893                        0                        0
# 1557478                        0                        0
# 2358323                        0                        0
# 1570964                        0                        0
# 2263664                        0                        0
# 889852                         0                        0
# 1177372                        0                        0
# 317802                         0                        0
# 1652147                        0                        0
# 1270575                        0                        0
# 1145057                        0                        0
# 2716152                        0                        0
# 1978030                        0                        0
# 1849130                        0                        0
# 614298                         0                        0
# 2749805                        0                        0
# 1744219                        0                        0
# 1109465                        0                        0
# 1973193                        0                        0
#
#          ACTIVACION_PORTACION_M4  file      tipo_id
# 1356281                        0  df06  desconocido
# 1261893                        0  df06  desconocido
# 1557478                        0  df06  desconocido
# 2358323                        0  df05  desconocido
# 1570964                        0  df05  desconocido
# 2263664                        0  df05  desconocido
# 889852                         0  df05  desconocido
# 1177372                        0  df05  desconocido
# 317802                         0  df05  desconocido
# 1652147                        0  df05  desconocido
# 1270575                        0  df05  desconocido
# 1145057                        0  df05  desconocido
# 2716152                        0  df07  desconocido
# 1978030                        0  df05  desconocido
# 1849130                        0  df05  desconocido
# 614298                         0  df05  desconocido
# 2749805                        0  df05  desconocido
# 1744219                        0  df05  desconocido
# 1109465                        0  df05  desconocido
# 1973193                        0  df05  desconocido

# %%
"""text='9005514169.0'
pos=text.find('.')
text[0:pos]
text[0:-1]"""
# Out:
# "text='9005514169.0'\npos=text.find('.')\ntext[0:pos]\ntext[0:-1]"

# %% [markdown]
# ###  Filtrar solo documentos con cédulas

# %%
df=df[df['tipo_id']=='cedula']

# %%
len(df)
# Out:
# 950408

# %%
df['POROUT'].value_counts()
# Out:
# 0    749131
# 1    201277
# Name: POROUT, dtype: int64

# %%
# agrupación por identificación
#df[['CO_ID']].groupby(by=['CO_ID']).count()
dup=df[['CO_ID','file']].value_counts().to_frame().sort_values(by=0, ascending=False)

# %%
dup.head(2)
# Out:
#                 0
# CO_ID     file
# 342999931 df05  2
# 242427134 df06  2

# %%
dup[0].value_counts()
# Out:
# 1    950400
# 2         4
# Name: 0, dtype: int64

# %%
dup[dup[0]==2]
# Out:
#                 0
# CO_ID     file
# 342999931 df05  2
# 242427134 df06  2
# 292720715 df05  2
# 343443993 df05  2

# %%
df[df['CO_ID']==292720715]
# Out:
#              CO_ID  CUSTOMER_ID     CUSTCODE   TELE_NUMB  TELE_NUMB_COMPLETO  \
# 1027770  292720715    302211904  2.207685723  3222684268        573222684268
# 1166204  292720715    302211904  2.207685723  3222684268        573222684268
#
#         IDENTIFICACION  FECHA_ACTIVACION_BSCS  POROUT REGION_SIT  \
# 1027770        8768800  2019-08-30 13:56:19.0       0      Costa
# 1166204        8768800  2019-08-30 13:56:19.0       0     Centro
#
#                MUNICIPIO_SIT     DEPTO_SIT REGION_SIT_NOCHE  \
# 1027770  Cartagena De Indias       Bolivar            Costa
# 1166204           Bogota D C  Cundinamarca           Centro
#
#          MUNICIPIO_SIT_NOCHE DEPTO_SIT_NOCHE REGION_SIT_M1 MUNICIPIO_SIT_M1  \
# 1027770  Cartagena De Indias         Bolivar           NaN              NaN
# 1166204           Bogota D C    Cundinamarca           NaN              NaN
#
#         DEPTO_SIT_M1 REGION_SIT_NOCHE_M1 MUNICIPIO_SIT_NOCHE_M1  \
# 1027770          NaN                 NaN                    NaN
# 1166204          NaN                 NaN                    NaN
#
#         DEPTO_SIT_NOCHE_M1  PROM_SEGUNDOS_MA  PROM_SEGUNDOS_M1  \
# 1027770                NaN           251.000               NaN
# 1166204                NaN           251.000               NaN
#
#          PROM_SEGUNDOS_M2  PROM_SEGUNDOS_M3  PROM_SEGUNDOS_M4  PROM_DATOS_MA  \
# 1027770            70.800            20.000            16.333        350.229
# 1166204            70.800            20.000            16.333        350.229
#
#          PROM_DATOS_M1  PROM_DATOS_M2  PROM_DATOS_M3  PROM_DATOS_M4  \
# 1027770        898.288       2127.810            NaN            NaN
# 1166204        898.288       2127.810            NaN            NaN
#
#          CANT_SMS_MA  CANT_SMS_M1  CANT_SMS_M2  CANT_SMS_M3  CANT_SMS_M4  \
# 1027770          NaN          NaN          NaN          NaN          NaN
# 1166204          NaN          NaN          NaN          NaN          NaN
#
#          TOTAL_MB_WHATSAPP  TOTAL_MB_TWITTER_Y_FACEBOOK  TOTAL_MB_SNAPCHAT  \
# 1027770              0.000                        0.000              0.000
# 1166204              0.000                        0.000              0.000
#
#          TOTAL_MB_INSTAGRAM  TOTAL_MB_WAZE  TOTAL_MB_YOUTUBE  \
# 1027770               0.000          0.000             0.000
# 1166204               0.000          0.000             0.000
#
#          TOTAL_MB_SPOTIFY  TOTAL_MB_GOOGLE_MAPS  CONSUMO_TOTAL_MB  \
# 1027770             0.000                 0.000             0.000
# 1166204             0.000                 0.000             0.000
#
#          CANT_PAQ_MAS_COMPRADO_MES  VLR_PAQ_MAS_COMPRADO_MES  \
# 1027770                        NaN                       NaN
# 1166204                        NaN                       NaN
#
#         NOMBRE_PAQ_MAS_COMPRADO_MES  PROMEDIO_SALDO_MES  PROMEDIO_SALDO_M1  \
# 1027770                         NaN             646.774                NaN
# 1166204                         NaN             646.774                NaN
#
#          PROMEDIO_SALDO_M2  ANTIGUEDAD_USUARIO  TOTAL_VALOR_DE_ADELANTA_SALDO  \
# 1027770                NaN             509.000                          0.000
# 1166204                NaN             509.000                          0.000
#
#          ES_SMARTPHONE  CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 1027770          1.000                                 NaN
# 1166204          1.000                                 NaN
#
#          VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 1027770                                NaN
# 1166204                                NaN
#
#         NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR RAZON1_MA  RAZON2_MA  RAZON3_MA  \
# 1027770                                  NaN       NaN        NaN        NaN
# 1166204                                  NaN       NaN        NaN        NaN
#
#         RAZON1_M1  RAZON2_M1  RAZON3_M1  RAZON1_M2 RAZON2_M2  RAZON3_M2  \
# 1027770       NaN        NaN        NaN        NaN       NaN        NaN
# 1166204       NaN        NaN        NaN        NaN       NaN        NaN
#
#          RAZON1_M3  RAZON2_M3 RAZON3_M3  RAZON1_M4  RAZON2_M4 RAZON3_M4  \
# 1027770        NaN        NaN       NaN        NaN        NaN       NaN
# 1166204        NaN        NaN       NaN        NaN        NaN       NaN
#
#          DESACTIVACION_PORTACION_M1  DESACTIVACION_PORTACION_M2  \
# 1027770                           0                           0
# 1166204                           0                           0
#
#          DESACTIVACION_PORTACION_M3  DESACTIVACION_PORTACION_M4  \
# 1027770                           0                           0
# 1166204                           0                           0
#
#          ACTIVACION_PORTACION_M1  ACTIVACION_PORTACION_M2  \
# 1027770                        0                        0
# 1166204                        0                        0
#
#          ACTIVACION_PORTACION_M3  ACTIVACION_PORTACION_M4  file tipo_id
# 1027770                        0                        0  df05  cedula
# 1166204                        0                        0  df05  cedula

# %%
## quitar duplicados
len(df)
# Out:
# 950408

# %%
df.drop_duplicates(subset=['CO_ID','file'], inplace=True)

# %%
df['POROUT'].isnull().sum()
# Out:
# 0

# %%
td_df=pd.pivot_table(df, index='CO_ID', columns='file', values='POROUT', aggfunc=np.sum, fill_value=0)

# %%
td_df['sel_porout']=td_df.max(axis=1)

# %%
td_df.head(10)
# Out:
# file     df05  df06  df07  sel_porout
# CO_ID
# 7045723     0     0     0           0
# 7153200     0     1     0           1
# 7166147     0     1     0           1
# 7236526     1     0     0           1
# 7360814     0     0     1           1
# 7360991     0     0     1           1
# 7407412     0     1     0           1
# 7414201     0     0     0           0
# 7490807     0     0     1           1
# 8060686     0     0     0           0

# %%
td_df['sel_porout'].value_counts()
# Out:
# 0    647047
# 1    201274
# Name: sel_porout, dtype: int64

# %%
td_df['sel_porout'].value_counts()/len(td_df)
# Out:
# 0   0.763
# 1   0.237
# Name: sel_porout, dtype: float64

# %% [markdown]
# ### Selección de variables

# %%
### varibles sin información

# %%
df.columns.values
# Out:
# array(['CO_ID', 'CUSTOMER_ID', 'CUSTCODE', 'TELE_NUMB',
#        'TELE_NUMB_COMPLETO', 'IDENTIFICACION', 'FECHA_ACTIVACION_BSCS',
#        'POROUT', 'REGION_SIT', 'MUNICIPIO_SIT', 'DEPTO_SIT',
#        'REGION_SIT_NOCHE', 'MUNICIPIO_SIT_NOCHE', 'DEPTO_SIT_NOCHE',
#        'REGION_SIT_M1', 'MUNICIPIO_SIT_M1', 'DEPTO_SIT_M1',
#        'REGION_SIT_NOCHE_M1', 'MUNICIPIO_SIT_NOCHE_M1',
#        'DEPTO_SIT_NOCHE_M1', 'PROM_SEGUNDOS_MA', 'PROM_SEGUNDOS_M1',
#        'PROM_SEGUNDOS_M2', 'PROM_SEGUNDOS_M3', 'PROM_SEGUNDOS_M4',
#        'PROM_DATOS_MA', 'PROM_DATOS_M1', 'PROM_DATOS_M2', 'PROM_DATOS_M3',
#        'PROM_DATOS_M4', 'CANT_SMS_MA', 'CANT_SMS_M1', 'CANT_SMS_M2',
#        'CANT_SMS_M3', 'CANT_SMS_M4', 'TOTAL_MB_WHATSAPP',
#        'TOTAL_MB_TWITTER_Y_FACEBOOK', 'TOTAL_MB_SNAPCHAT',
#        'TOTAL_MB_INSTAGRAM', 'TOTAL_MB_WAZE', 'TOTAL_MB_YOUTUBE',
#        'TOTAL_MB_SPOTIFY', 'TOTAL_MB_GOOGLE_MAPS', 'CONSUMO_TOTAL_MB',
#        'CANT_PAQ_MAS_COMPRADO_MES', 'VLR_PAQ_MAS_COMPRADO_MES',
#        'NOMBRE_PAQ_MAS_COMPRADO_MES', 'PROMEDIO_SALDO_MES',
#        'PROMEDIO_SALDO_M1', 'PROMEDIO_SALDO_M2', 'ANTIGUEDAD_USUARIO',
#        'TOTAL_VALOR_DE_ADELANTA_SALDO', 'ES_SMARTPHONE',
#        'CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR',
#        'VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR',
#        'NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR', 'RAZON1_MA', 'RAZON2_MA',
#        'RAZON3_MA', 'RAZON1_M1', 'RAZON2_M1', 'RAZON3_M1', 'RAZON1_M2',
#        'RAZON2_M2', 'RAZON3_M2', 'RAZON1_M3', 'RAZON2_M3', 'RAZON3_M3',
#        'RAZON1_M4', 'RAZON2_M4', 'RAZON3_M4',
#        'DESACTIVACION_PORTACION_M1', 'DESACTIVACION_PORTACION_M2',
#        'DESACTIVACION_PORTACION_M3', 'DESACTIVACION_PORTACION_M4',
#        'ACTIVACION_PORTACION_M1', 'ACTIVACION_PORTACION_M2',
#        'ACTIVACION_PORTACION_M3', 'ACTIVACION_PORTACION_M4', 'file',
#        'tipo_id'], dtype=object)

# %%
variablesSinInfo=df.nunique().to_frame()

# %%
## variables id

# %%
variablesSinInfo
# Out:
#                                            0
# CO_ID                                 848321
# CUSTOMER_ID                           848321
# CUSTCODE                              896094
# TELE_NUMB                             848262
# TELE_NUMB_COMPLETO                    848262
# IDENTIFICACION                        192838
# FECHA_ACTIVACION_BSCS                 760609
# POROUT                                     2
# REGION_SIT                                 5
# MUNICIPIO_SIT                            986
# DEPTO_SIT                                 33
# REGION_SIT_NOCHE                           5
# MUNICIPIO_SIT_NOCHE                      986
# DEPTO_SIT_NOCHE                           33
# REGION_SIT_M1                              5
# MUNICIPIO_SIT_M1                         987
# DEPTO_SIT_M1                              33
# REGION_SIT_NOCHE_M1                        5
# MUNICIPIO_SIT_NOCHE_M1                   987
# DEPTO_SIT_NOCHE_M1                        33
# PROM_SEGUNDOS_MA                      400740
# PROM_SEGUNDOS_M1                      394379
# PROM_SEGUNDOS_M2                      399218
# PROM_SEGUNDOS_M3                      390764
# PROM_SEGUNDOS_M4                      332985
# PROM_DATOS_MA                         470818
# PROM_DATOS_M1                         463942
# PROM_DATOS_M2                         463150
# PROM_DATOS_M3                         181567
# PROM_DATOS_M4                          93522
# CANT_SMS_MA                                0
# CANT_SMS_M1                                0
# CANT_SMS_M2                                0
# CANT_SMS_M3                                0
# CANT_SMS_M4                                0
# TOTAL_MB_WHATSAPP                       9081
# TOTAL_MB_TWITTER_Y_FACEBOOK            21804
# TOTAL_MB_SNAPCHAT                       1441
# TOTAL_MB_INSTAGRAM                      3178
# TOTAL_MB_WAZE                              1
# TOTAL_MB_YOUTUBE                        6021
# TOTAL_MB_SPOTIFY                           1
# TOTAL_MB_GOOGLE_MAPS                    1313
# CONSUMO_TOTAL_MB                       30577
# CANT_PAQ_MAS_COMPRADO_MES                 31
# VLR_PAQ_MAS_COMPRADO_MES                1674
# NOMBRE_PAQ_MAS_COMPRADO_MES               74
# PROMEDIO_SALDO_MES                    206007
# PROMEDIO_SALDO_M1                     192574
# PROMEDIO_SALDO_M2                     211618
# ANTIGUEDAD_USUARIO                      6271
# TOTAL_VALOR_DE_ADELANTA_SALDO             89
# ES_SMARTPHONE                              2
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR        31
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR       1706
# NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR      70
# RAZON1_MA                                 90
# RAZON2_MA                                  0
# RAZON3_MA                                  0
# RAZON1_M1                                 95
# RAZON2_M1                                  0
# RAZON3_M1                                  0
# RAZON1_M2                                  0
# RAZON2_M2                                 77
# RAZON3_M2                                  0
# RAZON1_M3                                  0
# RAZON2_M3                                  0
# RAZON3_M3                                 41
# RAZON1_M4                                  0
# RAZON2_M4                                  0
# RAZON3_M4                                 43
# DESACTIVACION_PORTACION_M1                 2
# DESACTIVACION_PORTACION_M2                 2
# DESACTIVACION_PORTACION_M3                 2
# DESACTIVACION_PORTACION_M4                 2
# ACTIVACION_PORTACION_M1                    2
# ACTIVACION_PORTACION_M2                    2
# ACTIVACION_PORTACION_M3                    2
# ACTIVACION_PORTACION_M4                    2
# file                                       3
# tipo_id                                    1

# %%
df['TOTAL_MB_WAZE'].value_counts()
# Out:
# 0.000    423945
# Name: TOTAL_MB_WAZE, dtype: int64

# %% [markdown]
# # Sin información de Waze o Spotify

# %%
variablesSinInfo[variablesSinInfo[0]<=1]
# Out:
#                   0
# CANT_SMS_MA       0
# CANT_SMS_M1       0
# CANT_SMS_M2       0
# CANT_SMS_M3       0
# CANT_SMS_M4       0
# TOTAL_MB_WAZE     1
# TOTAL_MB_SPOTIFY  1
# RAZON2_MA         0
# RAZON3_MA         0
# RAZON2_M1         0
# RAZON3_M1         0
# RAZON1_M2         0
# RAZON3_M2         0
# RAZON1_M3         0
# RAZON2_M3         0
# RAZON1_M4         0
# RAZON2_M4         0
# tipo_id           1

# %%
### eliminar columnas sin info
df.drop(columns=variablesSinInfo[variablesSinInfo[0]<=1].index.values, inplace=True)

# %%
### columnas ID
col_id=['CUSTOMER_ID','CUSTCODE','TELE_NUMB','TELE_NUMB_COMPLETO']
# 'CO_ID' como index

# %%
#df.drop(columns=['TELE_NUMB_COMPLETO'], inplace=True)
df.drop(columns=col_id, inplace=True)

# %%
### FECHA_ACTIVACION_BSCS

# %%
#df['FECHA_ACTIVACION_BSCS'] = df['FECHA_ACTIVACION_BSCS'].astype('datetime64[ns]')
df['FECHA_ACTIVACION_BSCS'] = df['FECHA_ACTIVACION_BSCS'].astype('datetime64[D]')

# %%
#df['FECHA_ACTIVACION_BSCS'].head(2)

# %%
maxFecha=max(df['FECHA_ACTIVACION_BSCS'])

# %%
df.dtypes['FECHA_ACTIVACION_BSCS']
# Out:
# dtype('<M8[ns]')

# %%
type(maxFecha)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#datetime.strptime(maxFecha, '%y-%m-d%')

# %%
df['ACTIGUEDAD_ACT_BSCS']=maxFecha-df['FECHA_ACTIVACION_BSCS']
#df['ACTIGUEDAD_ACT_BSCS']=(maxFecha-df['FECHA_ACTIVACION_BSCS']).astype(int)

# %%
df['ACTIGUEDAD_ACT_BSCS']=(df['ACTIGUEDAD_ACT_BSCS']/ np.timedelta64(1, 'D')).astype(int)

# %%
df.dtypes['ACTIGUEDAD_ACT_BSCS']
# Out:
# dtype('int32')

# %%
df['ACTIGUEDAD_ACT_BSCS'].head(2)
# Out:
# 6     920
# 9    1972
# Name: ACTIGUEDAD_ACT_BSCS, dtype: int32

# %%
df['ACTIGUEDAD_ACT_BSCS'].head(2)
#df.head(2)
# Out:
# 6     920
# 9    1972
# Name: ACTIGUEDAD_ACT_BSCS, dtype: int32

# %%
df.drop(columns=['FECHA_ACTIVACION_BSCS'],inplace=True)

# %%
df.head(2)
# Out:
#        CO_ID IDENTIFICACION  POROUT    REGION_SIT MUNICIPIO_SIT  DEPTO_SIT  \
# 6  275833170     1093221170       0  NorOccidente       Pereira  Risaralda
# 9  193337319       43902118       0  NorOccidente      Remedios  Antioquia
#
#   REGION_SIT_NOCHE MUNICIPIO_SIT_NOCHE DEPTO_SIT_NOCHE REGION_SIT_M1  \
# 6     NorOccidente             Pereira       Risaralda  NorOccidente
# 9     NorOccidente            Remedios       Antioquia  NorOccidente
#
#   MUNICIPIO_SIT_M1 DEPTO_SIT_M1 REGION_SIT_NOCHE_M1 MUNICIPIO_SIT_NOCHE_M1  \
# 6          Pereira    Risaralda        NorOccidente                Pereira
# 9         Remedios    Antioquia        NorOccidente               Remedios
#
#   DEPTO_SIT_NOCHE_M1  PROM_SEGUNDOS_MA  PROM_SEGUNDOS_M1  PROM_SEGUNDOS_M2  \
# 6          Risaralda           666.568           946.444           615.772
# 9          Antioquia           191.783           769.821           611.615
#
#    PROM_SEGUNDOS_M3  PROM_SEGUNDOS_M4  PROM_DATOS_MA  PROM_DATOS_M1  \
# 6           476.200           463.735         67.365          0.000
# 9           351.611           508.963            NaN            NaN
#
#    PROM_DATOS_M2  PROM_DATOS_M3  PROM_DATOS_M4  TOTAL_MB_WHATSAPP  \
# 6     128469.653            NaN            NaN              0.000
# 9            NaN            NaN            NaN                NaN
#
#    TOTAL_MB_TWITTER_Y_FACEBOOK  TOTAL_MB_SNAPCHAT  TOTAL_MB_INSTAGRAM  \
# 6                        0.000              0.000               0.000
# 9                          NaN                NaN                 NaN
#
#    TOTAL_MB_YOUTUBE  TOTAL_MB_GOOGLE_MAPS  CONSUMO_TOTAL_MB  \
# 6             0.000                 0.000             0.000
# 9               NaN                   NaN               NaN
#
#    CANT_PAQ_MAS_COMPRADO_MES  VLR_PAQ_MAS_COMPRADO_MES  \
# 6                        NaN                       NaN
# 9                        NaN                       NaN
#
#   NOMBRE_PAQ_MAS_COMPRADO_MES  PROMEDIO_SALDO_MES  PROMEDIO_SALDO_M1  \
# 6                         NaN             121.680            201.680
# 9                         NaN               0.000            584.967
#
#    PROMEDIO_SALDO_M2  ANTIGUEDAD_USUARIO  TOTAL_VALOR_DE_ADELANTA_SALDO  \
# 6              1.680             780.000                          0.000
# 9            856.097            1724.000                          0.000
#
#    ES_SMARTPHONE  CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 6          1.000                                 NaN
# 9          0.000                                 NaN
#
#    VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 6                                NaN                                  NaN
# 9                                NaN                                  NaN
#
#   RAZON1_MA RAZON1_M1 RAZON2_M2 RAZON3_M3 RAZON3_M4  \
# 6       NaN       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN       NaN
#
#    DESACTIVACION_PORTACION_M1  DESACTIVACION_PORTACION_M2  \
# 6                           0                           0
# 9                           0                           0
#
#    DESACTIVACION_PORTACION_M3  DESACTIVACION_PORTACION_M4  \
# 6                           0                           0
# 9                           0                           0
#
#    ACTIVACION_PORTACION_M1  ACTIVACION_PORTACION_M2  ACTIVACION_PORTACION_M3  \
# 6                        0                        0                        0
# 9                        0                        0                        0
#
#    ACTIVACION_PORTACION_M4  file  ACTIGUEDAD_ACT_BSCS
# 6                        0  df05                  920
# 9                        0  df05                 1972

# %%
df.columns.values
# Out:
# array(['CO_ID', 'IDENTIFICACION', 'POROUT', 'REGION_SIT', 'MUNICIPIO_SIT',
#        'DEPTO_SIT', 'REGION_SIT_NOCHE', 'MUNICIPIO_SIT_NOCHE',
#        'DEPTO_SIT_NOCHE', 'REGION_SIT_M1', 'MUNICIPIO_SIT_M1',
#        'DEPTO_SIT_M1', 'REGION_SIT_NOCHE_M1', 'MUNICIPIO_SIT_NOCHE_M1',
#        'DEPTO_SIT_NOCHE_M1', 'PROM_SEGUNDOS_MA', 'PROM_SEGUNDOS_M1',
#        'PROM_SEGUNDOS_M2', 'PROM_SEGUNDOS_M3', 'PROM_SEGUNDOS_M4',
#        'PROM_DATOS_MA', 'PROM_DATOS_M1', 'PROM_DATOS_M2', 'PROM_DATOS_M3',
#        'PROM_DATOS_M4', 'TOTAL_MB_WHATSAPP',
#        'TOTAL_MB_TWITTER_Y_FACEBOOK', 'TOTAL_MB_SNAPCHAT',
#        'TOTAL_MB_INSTAGRAM', 'TOTAL_MB_YOUTUBE', 'TOTAL_MB_GOOGLE_MAPS',
#        'CONSUMO_TOTAL_MB', 'CANT_PAQ_MAS_COMPRADO_MES',
#        'VLR_PAQ_MAS_COMPRADO_MES', 'NOMBRE_PAQ_MAS_COMPRADO_MES',
#        'PROMEDIO_SALDO_MES', 'PROMEDIO_SALDO_M1', 'PROMEDIO_SALDO_M2',
#        'ANTIGUEDAD_USUARIO', 'TOTAL_VALOR_DE_ADELANTA_SALDO',
#        'ES_SMARTPHONE', 'CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR',
#        'VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR',
#        'NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR', 'RAZON1_MA', 'RAZON1_M1',
#        'RAZON2_M2', 'RAZON3_M3', 'RAZON3_M4',
#        'DESACTIVACION_PORTACION_M1', 'DESACTIVACION_PORTACION_M2',
#        'DESACTIVACION_PORTACION_M3', 'DESACTIVACION_PORTACION_M4',
#        'ACTIVACION_PORTACION_M1', 'ACTIVACION_PORTACION_M2',
#        'ACTIVACION_PORTACION_M3', 'ACTIVACION_PORTACION_M4', 'file',
#        'ACTIGUEDAD_ACT_BSCS'], dtype=object)

# %%
len(df.columns.values)
# Out:
# 59

# %% [markdown]
# ### Variables categoricas

# %%
varid=['CO_ID', 'IDENTIFICACION']
varBin=['POROUT','ES_SMARTPHONE']
varNum=['TOTAL_VALOR_DE_ADELANTA_SALDO','file'] #revisar

# %%
varCatGeo=['REGION_SIT', 'MUNICIPIO_SIT','DEPTO_SIT', 'REGION_SIT_NOCHE', 'MUNICIPIO_SIT_NOCHE','DEPTO_SIT_NOCHE', 'REGION_SIT_M1', 'MUNICIPIO_SIT_M1',
       'DEPTO_SIT_M1', 'REGION_SIT_NOCHE_M1', 'MUNICIPIO_SIT_NOCHE_M1','DEPTO_SIT_NOCHE_M1']
varCatRazones=['RAZON1_MA', 'RAZON1_M1','RAZON2_M2', 'RAZON3_M3', 'RAZON3_M4']

# %%
varNumConLag=[ 'PROM_SEGUNDOS_MA', 'PROM_SEGUNDOS_M1','PROM_SEGUNDOS_M2', 'PROM_SEGUNDOS_M3', 'PROM_SEGUNDOS_M4',
              'PROM_DATOS_MA', 'PROM_DATOS_M1', 'PROM_DATOS_M2', 'PROM_DATOS_M3','PROM_DATOS_M4',
             'PROMEDIO_SALDO_MES', 'PROMEDIO_SALDO_M1', 'PROMEDIO_SALDO_M2']
varBinConLag=['DESACTIVACION_PORTACION_M1', 'DESACTIVACION_PORTACION_M2','DESACTIVACION_PORTACION_M3', 'DESACTIVACION_PORTACION_M4',
       'ACTIVACION_PORTACION_M1', 'ACTIVACION_PORTACION_M2','ACTIVACION_PORTACION_M3', 'ACTIVACION_PORTACION_M4']

# %%
varPaq=['NOMBRE_PAQ_MAS_COMPRADO_MES','CANT_PAQ_MAS_COMPRADO_MES','VLR_PAQ_MAS_COMPRADO_MES',
        'NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR','CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR','VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR']
varConsumo=['TOTAL_MB_WHATSAPP','TOTAL_MB_TWITTER_Y_FACEBOOK', 'TOTAL_MB_SNAPCHAT','TOTAL_MB_INSTAGRAM', 'TOTAL_MB_YOUTUBE', 'TOTAL_MB_GOOGLE_MAPS','CONSUMO_TOTAL_MB']

# %%
varAntiguedades=['ANTIGUEDAD_USUARIO','ACTIGUEDAD_ACT_BSCS']

# %%
df['RAZON1_M1'].value_counts()
# Out:
# CANCELACION - Solicitud                                          2498
# COMERCIAL - Condiciones de venta                                 1874
# INFORMACION - Informacion                                        1186
# INFORMACION - Sim card                                           1147
# FACTURACION - Explicacion factura                                 736
# COMERCIAL - Informacion                                           684
# INFORMACION - Suspension                                          650
# VOZ Y DATOS - Servicios adicioales                                317
# COMERCIAL - Informacion                                           301
# INFORMACION - Equipo                                              296
# CANCELACION - Informacion                                         291
# PQR - PQR                                                         226
# COBRO - Equipo                                                    215
# SERVICIO - Equipo                                                 199
# COBRO - Soporte                                                   191
# COMERCIAL - Servicios adicioales                                  178
# COBRO - Cobros                                                    162
# SERVICIO - Llamadas                                               151
# COMERCIAL - Solictud                                              144
# COBRO - Explicacion factura                                       143
# CANCELACION - Plan                                                138
# INFORMACION - Tramite                                             134
# INFORMACION - Servicios prepago                                   132
# VOZ Y DATOS - Datos Moviles                                       132
# INFORMACION - Certificaci?n                                       112
# VOZ Y DATOS - Voz movil                                           110
# SERVICIO - Soporte                                                109
# COMERCIAL - Contrato                                              108
# INFORMACION - Servicios adicioales                                104
# FACTURACION - Servicios prepago                                    92
# PAGO - Pagos                                                       79
# INFORMACION - Contrato                                             73
# INFORMACION - Certificacion                                        71
# VOZ Y DATOS - Mensajeria                                           70
# VOZ Y DATOS - Voz y Datos                                          64
# CANCELACION - Informacion                                          58
# COMERCIAL - Servicios hogares                                      53
# COBRO - Contrato                                                   45
# INFORMACION - Consumos                                             42
# INFORMACION - Aplicacion de terceros                               38
# INFORMACION - Datos pesonales                                      37
# EQUIPO - Equipo                                                    36
# SERVICIO - Fraude                                                  31
# INFORMACION - Reconexion                                           31
# INFORMACION - Plan                                                 30
# FACTURACION - Compensacion                                         30
# COBRO - Servicios adicioales                                       25
# INFORMACION - Voz y Datos                                          25
# INFORMACION - Solicitud                                            22
# COBRO - Limite de credito                                          22
# CANCELACION - Intencion de cancelacion                             21
# EQUIPO - Equipo terminal                                           20
# COMERCIAL - Elegidos                                               19
# INFORMACION - Servicios hogares                                    18
# INFORMACION - Elegidos                                             18
# COMERCIAL - Servicios prepago                                      16
# VOZ Y DATOS - Pagos                                                16
# INFORMACION - Equipo terminal                                      15
# INFORMACION - Informacion                                          14
# COMERCIAL - Servicios adicionales                                  13
# VOZ Y DATOS - Voz y Datos moviles                                  13
# COBRO - Pagos                                                      10
# SERVICIO - Sim card                                                 9
# SERVICIO - Tranferencia                                             8
# SERVICIO - Datos Moviles                                            7
# INFORMACION - Soporte                                               7
# INFORMACION - Pagos                                                 7
# SERVICIO - Voz y Datos                                              7
# COMERCIAL - Retencion                                               6
# VOZ Y DATOS - Servicios adicionales                                 6
# FACTURACION - Factura fisica                                        6
# COMERCIAL - Soporte                                                 5
# INFORMACION - Incremento tarifas                                    5
# VOZ Y DATOS - Soporte                                               5
# COMERCIAL - Incremento tarifas                                      4
# INFORMACION - Fraude                                                4
# COMERCIAL - Otras consultas                                         3
# INFORMACION - Otras consultas                                       3
# SERVICIO - Informacion                                              3
# CANCELACION - Contrato                                              3
# COMERCIAL - Datos Moviles                                           3
# VOZ Y DATOS - Elegidos                                              3
# SERVICIO - Voz movil                                                2
# CANCELACION - Servicios adicioales                                  2
# COMERCIAL - Inconveniente                                           2
# INFORMACION - Datos Moviles                                         2
# COMERCIAL - Distribuidor                                            1
# COBRO - Voz y Datos moviles                                         1
# COBRO - Informacion                                                 1
# VOZ Y DATOS - Contrato                                              1
# VOZ Y DATOS - Telefonia Fija                                        1
# INFORMACION - Todos los servicios                                   1
# COMERCIAL - Inconformidad mensajes de suscripcion y contenido       1
# INFORMACION - Servicios adicionales                                 1
# VOZ Y DATOS - Inconveniente                                         1
# Name: RAZON1_M1, dtype: int64

# %%
(len(varid)+len(varBin)+len(varCatGeo)+len(varCatRazones)+len(varNumConLag)+len(varBinConLag)+len(varPaq)+len(varConsumo)+len(varAntiguedades))
# Out:
# 57

# %%
df.describe().T
# Out:
#                                         count          mean          std  \
# CO_ID                              950404.000 267012684.811 77159699.317
# POROUT                             950404.000         0.212        0.409
# PROM_SEGUNDOS_MA                   617592.000       329.357      311.442
# PROM_SEGUNDOS_M1                   616892.000       332.500      314.651
# PROM_SEGUNDOS_M2                   620339.000       329.498      312.150
# PROM_SEGUNDOS_M3                   616382.000       331.732      317.870
# PROM_SEGUNDOS_M4                   508222.000       336.106      319.620
# PROM_DATOS_MA                      511102.000   5231576.176 10088143.018
# PROM_DATOS_M1                      504757.000   4958883.373 10312483.408
# PROM_DATOS_M2                      503667.000   4790612.977 10253245.264
# PROM_DATOS_M3                      192986.000   4831487.138 10199872.352
# PROM_DATOS_M4                       99066.000   4749245.470 10357954.386
# TOTAL_MB_WHATSAPP                  423945.000       546.462     1331.610
# TOTAL_MB_TWITTER_Y_FACEBOOK        423945.000      1791.990     4703.271
# TOTAL_MB_SNAPCHAT                  423945.000        18.657       87.498
# TOTAL_MB_INSTAGRAM                 423945.000        43.296      302.155
# TOTAL_MB_YOUTUBE                   423945.000       246.370      708.813
# TOTAL_MB_GOOGLE_MAPS               423945.000         6.427       73.348
# CONSUMO_TOTAL_MB                   423945.000      3601.460     7127.497
# CANT_PAQ_MAS_COMPRADO_MES          123897.000         2.363        2.848
# VLR_PAQ_MAS_COMPRADO_MES           123897.000     -3648.026     4543.509
# PROMEDIO_SALDO_MES                 563460.000      1152.324     7946.985
# PROMEDIO_SALDO_M1                  554196.000      1162.860     8185.405
# PROMEDIO_SALDO_M2                  569101.000      1158.703     8194.971
# ANTIGUEDAD_USUARIO                 520454.000      1256.591     1205.711
# TOTAL_VALOR_DE_ADELANTA_SALDO      463880.000        67.042      626.354
# ES_SMARTPHONE                      563460.000         0.752        0.432
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR 112360.000         2.178        2.492
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR  112360.000     -3627.869     4757.259
# DESACTIVACION_PORTACION_M1         950404.000         0.000        0.009
# DESACTIVACION_PORTACION_M2         950404.000         0.000        0.015
# DESACTIVACION_PORTACION_M3         950404.000         0.000        0.016
# DESACTIVACION_PORTACION_M4         950404.000         0.000        0.009
# ACTIVACION_PORTACION_M1            950404.000         0.004        0.060
# ACTIVACION_PORTACION_M2            950404.000         0.011        0.106
# ACTIVACION_PORTACION_M3            950404.000         0.009        0.097
# ACTIVACION_PORTACION_M4            950404.000         0.005        0.072
# ACTIGUEDAD_ACT_BSCS                950404.000      1137.510     1150.409
#
#                                            min           25%           50%  \
# CO_ID                              7045723.000 229233686.000 281637251.000
# POROUT                                   0.000         0.000         0.000
# PROM_SEGUNDOS_MA                         0.000       135.203       245.149
# PROM_SEGUNDOS_M1                         0.000       135.313       247.211
# PROM_SEGUNDOS_M2                         0.000       134.111       244.548
# PROM_SEGUNDOS_M3                         0.000       134.042       245.400
# PROM_SEGUNDOS_M4                         0.000       135.092       249.200
# PROM_DATOS_MA                            0.000     25062.256   1423188.027
# PROM_DATOS_M1                            0.000     23153.316   1257582.742
# PROM_DATOS_M2                            0.000     25092.274   1240921.411
# PROM_DATOS_M3                            0.000     44761.233   1423330.800
# PROM_DATOS_M4                            0.000     45483.684   1416144.377
# TOTAL_MB_WHATSAPP                        0.000         1.000        91.000
# TOTAL_MB_TWITTER_Y_FACEBOOK              0.000         0.000       152.000
# TOTAL_MB_SNAPCHAT                        0.000         0.000         0.000
# TOTAL_MB_INSTAGRAM                       0.000         0.000         0.000
# TOTAL_MB_YOUTUBE                         0.000         0.000        22.000
# TOTAL_MB_GOOGLE_MAPS                     0.000         0.000         0.000
# CONSUMO_TOTAL_MB                         0.000        32.000       771.000
# CANT_PAQ_MAS_COMPRADO_MES                1.000         1.000         1.000
# VLR_PAQ_MAS_COMPRADO_MES           -257400.000     -4000.000     -2000.000
# PROMEDIO_SALDO_MES                       0.000         0.100        32.258
# PROMEDIO_SALDO_M1                        0.000         0.190        33.333
# PROMEDIO_SALDO_M2                        0.000         0.230        35.983
# ANTIGUEDAD_USUARIO                      -1.000       284.000       914.000
# TOTAL_VALOR_DE_ADELANTA_SALDO            0.000         0.000         0.000
# ES_SMARTPHONE                            0.000         1.000         1.000
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR       1.000         1.000         1.000
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR  -514800.000     -4000.000     -2000.000
# DESACTIVACION_PORTACION_M1               0.000         0.000         0.000
# DESACTIVACION_PORTACION_M2               0.000         0.000         0.000
# DESACTIVACION_PORTACION_M3               0.000         0.000         0.000
# DESACTIVACION_PORTACION_M4               0.000         0.000         0.000
# ACTIVACION_PORTACION_M1                  0.000         0.000         0.000
# ACTIVACION_PORTACION_M2                  0.000         0.000         0.000
# ACTIVACION_PORTACION_M3                  0.000         0.000         0.000
# ACTIVACION_PORTACION_M4                  0.000         0.000         0.000
# ACTIGUEDAD_ACT_BSCS                      0.000       241.000       844.000
#
#                                              75%           max
# CO_ID                              332161763.500 352353868.000
# POROUT                                     0.000         1.000
# PROM_SEGUNDOS_MA                         422.951     28322.778
# PROM_SEGUNDOS_M1                         427.603     20355.316
# PROM_SEGUNDOS_M2                         423.426     21427.894
# PROM_SEGUNDOS_M3                         425.938     34042.000
# PROM_SEGUNDOS_M4                         433.245     15141.811
# PROM_DATOS_MA                        5965031.696 457774549.395
# PROM_DATOS_M1                        5324508.272 752477712.635
# PROM_DATOS_M2                        4940722.719 876200918.885
# PROM_DATOS_M3                        5000658.814 418383861.333
# PROM_DATOS_M4                        4798290.686 637956141.333
# TOTAL_MB_WHATSAPP                        505.000     76509.000
# TOTAL_MB_TWITTER_Y_FACEBOOK             1351.000    289977.000
# TOTAL_MB_SNAPCHAT                          4.000      3967.000
# TOTAL_MB_INSTAGRAM                         2.000     34085.000
# TOTAL_MB_YOUTUBE                         165.000     29953.000
# TOTAL_MB_GOOGLE_MAPS                       0.000      7418.000
# CONSUMO_TOTAL_MB                        3862.000    301668.000
# CANT_PAQ_MAS_COMPRADO_MES                  2.000        31.000
# VLR_PAQ_MAS_COMPRADO_MES               -1500.000      -200.000
# PROMEDIO_SALDO_MES                       786.934   2695932.868
# PROMEDIO_SALDO_M1                        800.000   2702990.070
# PROMEDIO_SALDO_M2                        797.443   2693630.514
# ANTIGUEDAD_USUARIO                      1763.000      6576.000
# TOTAL_VALOR_DE_ADELANTA_SALDO              0.000    145000.000
# ES_SMARTPHONE                              1.000         1.000
# CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR         2.000        31.000
# VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR      -1500.000         0.000
# DESACTIVACION_PORTACION_M1                 0.000         1.000
# DESACTIVACION_PORTACION_M2                 0.000         1.000
# DESACTIVACION_PORTACION_M3                 0.000         1.000
# DESACTIVACION_PORTACION_M4                 0.000         1.000
# ACTIVACION_PORTACION_M1                    0.000         1.000
# ACTIVACION_PORTACION_M2                    0.000         1.000
# ACTIVACION_PORTACION_M3                    0.000         1.000
# ACTIVACION_PORTACION_M4                    0.000         1.000
# ACTIGUEDAD_ACT_BSCS                     1598.000      6605.000

# %% [markdown]
# ##  Ejercicio 1
# * Medidas de agrupación variables (tendencia y promedio)
# * Selección de casos  (ultimo caso para los clientes sin porout).  mmm ultimo archivo por cliente
# * Ejercicio 2, es sin seleccionar ultimos caso
#
# * Ejercicio 1: clientes con Porout (3 meses) vs clientes sin port
# * Ejercicio 2: clientes con porout por mes.  El mismo cliente aparece como sin porout un mes y como porout en otro

# %% [markdown]
# #### Máximo archivo por cliente

# %%
maxFile=df.groupby(['CO_ID'])['file'].max().to_frame()

# %%
maxFile.reset_index(inplace=True)

# %%
maxFile.head(2)
# Out:
#      CO_ID  file
# 0  7045723  df05
# 1  7153200  df06

# %%
# merged_df = left_df.merge(right_df, how='inner', left_on=["A", "B"], right_on=["A2","B2"])
tabla_1 = maxFile.merge(df, how='left', left_on=["CO_ID", "file"], right_on=["CO_ID", "file"])

# %%
tabla_1.head(2)
# Out:
#      CO_ID  file IDENTIFICACION  POROUT REGION_SIT MUNICIPIO_SIT DEPTO_SIT  \
# 0  7045723  df05       41939455       0        NaN           NaN       NaN
# 1  7153200  df06       51832393       1        NaN           NaN       NaN
#
#   REGION_SIT_NOCHE MUNICIPIO_SIT_NOCHE DEPTO_SIT_NOCHE REGION_SIT_M1  \
# 0              NaN                 NaN             NaN           NaN
# 1              NaN                 NaN             NaN           NaN
#
#   MUNICIPIO_SIT_M1 DEPTO_SIT_M1 REGION_SIT_NOCHE_M1 MUNICIPIO_SIT_NOCHE_M1  \
# 0              NaN          NaN                 NaN                    NaN
# 1              NaN          NaN                 NaN                    NaN
#
#   DEPTO_SIT_NOCHE_M1  PROM_SEGUNDOS_MA  PROM_SEGUNDOS_M1  PROM_SEGUNDOS_M2  \
# 0                NaN               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
#
#    PROM_SEGUNDOS_M3  PROM_SEGUNDOS_M4  PROM_DATOS_MA  PROM_DATOS_M1  \
# 0               NaN               NaN            NaN            NaN
# 1           231.667               NaN      25662.357       5325.175
#
#    PROM_DATOS_M2  PROM_DATOS_M3  PROM_DATOS_M4  TOTAL_MB_WHATSAPP  \
# 0            NaN            NaN            NaN                NaN
# 1          0.000    4789059.524            NaN                NaN
#
#    TOTAL_MB_TWITTER_Y_FACEBOOK  TOTAL_MB_SNAPCHAT  TOTAL_MB_INSTAGRAM  \
# 0                          NaN                NaN                 NaN
# 1                          NaN                NaN                 NaN
#
#    TOTAL_MB_YOUTUBE  TOTAL_MB_GOOGLE_MAPS  CONSUMO_TOTAL_MB  \
# 0               NaN                   NaN               NaN
# 1               NaN                   NaN               NaN
#
#    CANT_PAQ_MAS_COMPRADO_MES  VLR_PAQ_MAS_COMPRADO_MES  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
#
#   NOMBRE_PAQ_MAS_COMPRADO_MES  PROMEDIO_SALDO_MES  PROMEDIO_SALDO_M1  \
# 0                         NaN                 NaN                NaN
# 1                         NaN                 NaN           2258.065
#
#    PROMEDIO_SALDO_M2  ANTIGUEDAD_USUARIO  TOTAL_VALOR_DE_ADELANTA_SALDO  \
# 0                NaN                 NaN                            NaN
# 1                NaN                 NaN                            NaN
#
#    ES_SMARTPHONE  CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 0            NaN                                 NaN
# 1            NaN                                 NaN
#
#    VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
#
#   RAZON1_MA RAZON1_M1 RAZON2_M2 RAZON3_M3 RAZON3_M4  \
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
#
#    DESACTIVACION_PORTACION_M1  DESACTIVACION_PORTACION_M2  \
# 0                           0                           0
# 1                           0                           0
#
#    DESACTIVACION_PORTACION_M3  DESACTIVACION_PORTACION_M4  \
# 0                           0                           0
# 1                           0                           0
#
#    ACTIVACION_PORTACION_M1  ACTIVACION_PORTACION_M2  ACTIVACION_PORTACION_M3  \
# 0                        0                        0                        0
# 1                        0                        0                        0
#
#    ACTIVACION_PORTACION_M4  ACTIGUEDAD_ACT_BSCS
# 0                        0                 6605
# 1                        0                 6591

# %% [markdown]
# ### Agrupacion promedio y tendencia

# %%
#variables
varMedidas=['PROM_SEGUNDOS','PROM_DATOS','PROMEDIO_SALDO']

# %% [markdown]
# #### Promedio

# %%
tabla_1.filter(regex='^PROM_SEGUNDOS',axis=1).head()
# Out:
#    PROM_SEGUNDOS_MA  PROM_SEGUNDOS_M1  PROM_SEGUNDOS_M2  PROM_SEGUNDOS_M3  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN           231.667
# 2           655.926           341.348           318.590           299.633
# 3           380.500           233.800           621.250               NaN
# 4           438.707           518.259           378.987           300.661
#
#    PROM_SEGUNDOS_M4
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4           339.817

# %%
tabla_1.filter(regex='^PROM_SEGUNDOS',axis=1).iloc[4]
# Out:
# PROM_SEGUNDOS_MA   438.707
# PROM_SEGUNDOS_M1   518.259
# PROM_SEGUNDOS_M2   378.987
# PROM_SEGUNDOS_M3   300.661
# PROM_SEGUNDOS_M4   339.817
# Name: 4, dtype: float64

# %%
#tabla_1.iloc[4]

# %%
tabla_1['avg_PROM_SEGUNDOS']=tabla_1.filter(regex='^PROM_SEGUNDOS',axis=1).mean(axis=1)

# %%
tabla_1['avg_PROM_SEGUNDOS'].head()
# Out:
# 0       NaN
# 1   231.667
# 2   403.874
# 3   411.850
# 4   395.286
# Name: avg_PROM_SEGUNDOS, dtype: float64

# %%
#PROM_DATOS
tabla_1.filter(regex='^PROM_DATOS',axis=1).head(20)
# Out:
#     PROM_DATOS_MA  PROM_DATOS_M1  PROM_DATOS_M2  PROM_DATOS_M3  PROM_DATOS_M4
# 0             NaN            NaN            NaN            NaN            NaN
# 1       25662.357       5325.175          0.000    4789059.524            NaN
# 2     2884460.709          8.552     318952.160       8170.538            NaN
# 3      381114.714            NaN            NaN            NaN            NaN
# 4       18618.000    5489566.600   21644303.447        135.000      29484.400
# 5       95912.306     395327.725     222666.115      34335.921     632445.873
# 6     7428231.786    7219155.095    2064861.762    2244865.745            NaN
# 7             NaN            NaN            NaN            NaN            NaN
# 8          28.895        117.861        743.803       2555.178        980.150
# 9    15080547.186   14775407.700    6731867.269    7218381.094            NaN
# 10    1440393.385      12682.143      28668.045    1324926.370            NaN
# 11            NaN            NaN            NaN            NaN            NaN
# 12      17090.407   14547018.175   13697201.758            NaN            NaN
# 13       7786.727       6396.076            NaN            NaN            NaN
# 14            NaN            NaN            NaN            NaN            NaN
# 15     202316.020     143573.588            NaN            NaN            NaN
# 16            NaN            NaN      69334.141            NaN            NaN
# 17      55506.371      64219.235      53822.907      87771.500      80084.773
# 18          0.000          0.000          0.000            NaN            NaN
# 19    2067593.082    5347121.482    1978135.006     757935.012     779739.137

# %%
tabla_1['avg_PROM_DATOS']=tabla_1.filter(regex='^PROM_DATOS',axis=1).mean(axis=1)

# %%
tabla_1['avg_PROM_DATOS'].head()
# Out:
# 0           NaN
# 1   1205011.764
# 2    802897.989
# 3    381114.714
# 4   5436421.489
# Name: avg_PROM_DATOS, dtype: float64

# %%
tabla_1.filter(regex='^PROMEDIO_SALDO',axis=1).head(15)
# Out:
#     PROMEDIO_SALDO_MES  PROMEDIO_SALDO_M1  PROMEDIO_SALDO_M2
# 0                  NaN                NaN                NaN
# 1                  NaN           2258.065                NaN
# 2             1208.233           3097.539          10470.967
# 3                0.000                NaN                NaN
# 4             3918.053          12444.077          12279.255
# 5              469.132           1343.133           6694.842
# 6                4.170              4.170              4.170
# 7             2842.074           2997.405           2237.180
# 8             9115.787          28913.377          20195.491
# 9             1336.263           6454.543            669.597
# 10               2.650                NaN              2.650
# 11                 NaN                NaN                NaN
# 12                 NaN              1.930              1.930
# 13               2.150              2.150              2.150
# 14           43950.218          80350.460          76723.541

# %%
tabla_1['avg_PROMEDIO_SALDO']=tabla_1.filter(regex='^PROMEDIO_SALDO',axis=1).mean(axis=1)

# %%
tabla_1['avg_PROMEDIO_SALDO'].head()
# Out:
# 0        NaN
# 1   2258.065
# 2   4925.580
# 3      0.000
# 4   9547.128
# Name: avg_PROMEDIO_SALDO, dtype: float64

# %% [markdown]
# ### STD

# %%
def categorizacion_std(x):
    corte_up=0.5    
    if ( np.isnan(x) ):
        return np.NAN
    elif(x>corte_up):
        return "dispersed"   
    else:
        return "united"

# %%
def categorizacion_std2(x, q1=0.2 , q2=0.5):
    corte_up=0.5    
    if ( np.isnan(x) ):
        return np.NAN
    elif(x>q2):
        return "dispersed"   
    elif(x>q1):
        return "moderate"
    else:
        return "united"

# %%
#df.std(axis=1)
tabla_1['STD_PROM_DATOS']=tabla_1.filter(regex='^PROM_DATOS',axis=1).std(axis=1)

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['STD_PROM_DATOS']);
#ax.set_xlim(-1000,1000)

# %%
tabla_1['STD_PROM_DATOS_cat']=tabla_1['STD_PROM_DATOS']/tabla_1['avg_PROM_DATOS']

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['STD_PROM_DATOS_cat']);

# %%
q1=tabla_1['STD_PROM_DATOS_cat'].quantile(0.33)
q2=tabla_1['STD_PROM_DATOS_cat'].quantile(0.66)

# %%
tabla_1['STD_PROM_DATOS_cat2']=tabla_1['STD_PROM_DATOS_cat'].apply(categorizacion_std2,q1=q1, q2=q2)

# %%
tabla_1['STD_PROM_DATOS_cat2'].isnull().sum()
# Out:
# 393637

# %%
tabla_1['STD_PROM_DATOS_cat2'].value_counts()
# Out:
# dispersed    154593
# united       150046
# moderate     150045
# Name: STD_PROM_DATOS_cat2, dtype: int64

# %%
tabla_1['STD_PROM_SEGUNDOS']=tabla_1.filter(regex='^PROM_SEGUNDOS',axis=1).std(axis=1)

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['STD_PROM_SEGUNDOS']);

# %%
tabla_1['STD_PROM_SEGUNDOS_cat']=tabla_1['STD_PROM_SEGUNDOS']/tabla_1['avg_PROM_SEGUNDOS']

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['STD_PROM_SEGUNDOS_cat']);

# %%
q1=tabla_1['STD_PROM_SEGUNDOS_cat'].quantile(0.33)
q2=tabla_1['STD_PROM_SEGUNDOS_cat'].quantile(0.66)

# %%
tabla_1['STD_PROM_SEGUNDOS_cat2']=tabla_1['STD_PROM_SEGUNDOS_cat'].apply(categorizacion_std2, q1=q1, q2=q2)

# %%
tabla_1['STD_PROM_SEGUNDOS_cat2'].isnull().sum()
# Out:
# 264688

# %%
tabla_1['STD_PROM_SEGUNDOS_cat2'].value_counts()
# Out:
# dispersed    198435
# united       192599
# moderate     192599
# Name: STD_PROM_SEGUNDOS_cat2, dtype: int64

# %%
#tabla_1['slope_PROM_SEGUNDOS_cat']=tabla_1['slope_PROM_SEGUNDOS']/tabla_1['avg_PROM_SEGUNDOS']
#tabla_1['STD_PROM_DATOS_cat']

# %%
#PROMEDIO_SALDO

# %%
tabla_1['STD_PROMEDIO_SALDO']=tabla_1.filter(regex='^PROMEDIO_SALDO',axis=1).std(axis=1)

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['STD_PROMEDIO_SALDO']);

# %%
tabla_1['STD_PROMEDIO_SALDO_cat']=tabla_1['STD_PROMEDIO_SALDO']/tabla_1['avg_PROMEDIO_SALDO']

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['STD_PROMEDIO_SALDO_cat']);

# %%
q1=tabla_1['STD_PROMEDIO_SALDO_cat'].quantile(0.33)
q2=tabla_1['STD_PROMEDIO_SALDO_cat'].quantile(0.66)

# %%
tabla_1['STD_PROMEDIO_SALDO_cat2']=tabla_1['STD_PROMEDIO_SALDO_cat'].apply(categorizacion_std2, q1=q1, q2=q2)

# %%
tabla_1['STD_PROMEDIO_SALDO_cat2'].isnull().sum()
# Out:
# 433172

# %%
tabla_1['STD_PROMEDIO_SALDO_cat2'].value_counts()
# Out:
# dispersed    141151
# united       136999
# moderate     136999
# Name: STD_PROMEDIO_SALDO_cat2, dtype: int64

# %% [markdown]
# ### Tendencia

# %%
## Tendencia
def calcSlope(data, order=1):
    ind= list(reversed(range(0,len(data))))
    #print(ind)
    #print(data)
    #print(np.isfinite(data))
    idx=np.isfinite(ind) & np.isfinite(data)
    if idx.sum()<=1 :
        return np.NAN
    else:
        #print(list(compress(ind, idx)))
        ind=list(compress(ind, idx))
        data=list(compress(data, idx))
        coeffs = np.polyfit(ind, data, order)
        slope = coeffs[-2]
        return float(slope)

# %%
def calcSlopeRow(row,prefix):
    ##data=row.filter(regex='^'+prefix,axis=1).values    
    data=list(row.filter(regex='^'+prefix).values)
    ##return calcSlope(data[0])
    if(data.count('Nan')==len(data)):
        return np.NAN
    else:
        return calcSlope(data)

# %%
#tweetsDFProcesado['tokens']=tweetsDFProcesado.apply(lambda x: seleccionTokenizacion(x,'full_text_Limpio'), axis=1)

# %%
#tabla_1['slope_PROM_SEGUNDOS']=tabla_1.filter(regex='^PROM_DATOS',axis=1).mean(axis=1)
tabla_1['slope_PROM_SEGUNDOS']=tabla_1.apply(lambda x: calcSlopeRow(x,'PROM_SEGUNDOS'), axis=1)

# %%
len(tabla_1)
# Out:
# 848321

# %%
tabla_1['slope_PROM_SEGUNDOS'].isnull().sum()
# Out:
# 264686

# %%
#tabla_1['slope_PROM_SEGUNDOS'].describe

# %%
#sns.violinplot(ax=axs[0],x=df_serie["PORCENTAJEPL"]);
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['slope_PROM_SEGUNDOS']);
ax.set_xlim(-1000,1000)
# Out:
# (-1000.0, 1000.0)

# %%
tabla_1['slope_PROM_SEGUNDOS_cat']=tabla_1['slope_PROM_SEGUNDOS']/tabla_1['avg_PROM_SEGUNDOS']

# %%
tabla_1[['slope_PROM_SEGUNDOS_cat']].describe()
# Out:
#        slope_PROM_SEGUNDOS_cat
# count               583633.000
# mean                    -0.010
# std                      0.297
# min                     -2.000
# 25%                     -0.111
# 50%                     -0.005
# 75%                      0.099
# max                      2.000

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['slope_PROM_SEGUNDOS_cat']);

# %%
def categorizacion(x):
    corte_up=0.1
    corte_dw=-0.1
    if ( np.isnan(x) ):
        return np.NAN
    elif(x>corte_up):
        return "increase"
    elif(x<corte_dw):
        return "decrease"
    else:
        return "noTrend"

# %%
tabla_1['slope_PROM_SEGUNDOS_cat2']=tabla_1['slope_PROM_SEGUNDOS_cat'].apply(categorizacion)

# %%
tabla_1['slope_PROM_SEGUNDOS_cat2'].isnull().sum()
# Out:
# 264688

# %%
tabla_1['slope_PROM_SEGUNDOS_cat2'].value_counts()
# Out:
# noTrend     281098
# decrease    157872
# increase    144663
# Name: slope_PROM_SEGUNDOS_cat2, dtype: int64

# %%
tabla_1.iloc[[0,4,10]]
# Out:
#       CO_ID  file IDENTIFICACION  POROUT    REGION_SIT MUNICIPIO_SIT  \
# 0   7045723  df05       41939455       0           NaN           NaN
# 4   7360814  df07       79556158       1  NorOccidente       Armenia
# 10  8284770  df06       52503312       1           NaN           NaN
#
#    DEPTO_SIT REGION_SIT_NOCHE MUNICIPIO_SIT_NOCHE DEPTO_SIT_NOCHE  \
# 0        NaN              NaN                 NaN             NaN
# 4    Quindio     NorOccidente             Armenia         Quindio
# 10       NaN              NaN                 NaN             NaN
#
#    REGION_SIT_M1 MUNICIPIO_SIT_M1 DEPTO_SIT_M1 REGION_SIT_NOCHE_M1  \
# 0            NaN              NaN          NaN                 NaN
# 4   NorOccidente          Armenia      Quindio        NorOccidente
# 10           NaN              NaN          NaN                 NaN
#
#    MUNICIPIO_SIT_NOCHE_M1 DEPTO_SIT_NOCHE_M1  PROM_SEGUNDOS_MA  \
# 0                     NaN                NaN               NaN
# 4                 Armenia            Quindio           438.707
# 10                    NaN                NaN           379.693
#
#     PROM_SEGUNDOS_M1  PROM_SEGUNDOS_M2  PROM_SEGUNDOS_M3  PROM_SEGUNDOS_M4  \
# 0                NaN               NaN               NaN               NaN
# 4            518.259           378.987           300.661           339.817
# 10           418.151           571.491           622.312               NaN
#
#     PROM_DATOS_MA  PROM_DATOS_M1  PROM_DATOS_M2  PROM_DATOS_M3  PROM_DATOS_M4  \
# 0             NaN            NaN            NaN            NaN            NaN
# 4       18618.000    5489566.600   21644303.447        135.000      29484.400
# 10    1440393.385      12682.143      28668.045    1324926.370            NaN
#
#     TOTAL_MB_WHATSAPP  TOTAL_MB_TWITTER_Y_FACEBOOK  TOTAL_MB_SNAPCHAT  \
# 0                 NaN                          NaN                NaN
# 4               0.000                        0.000              0.000
# 10             39.000                        1.000              0.000
#
#     TOTAL_MB_INSTAGRAM  TOTAL_MB_YOUTUBE  TOTAL_MB_GOOGLE_MAPS  \
# 0                  NaN               NaN                   NaN
# 4                0.000             0.000                 0.000
# 10               0.000            21.000                 0.000
#
#     CONSUMO_TOTAL_MB  CANT_PAQ_MAS_COMPRADO_MES  VLR_PAQ_MAS_COMPRADO_MES  \
# 0                NaN                        NaN                       NaN
# 4              0.000                        NaN                       NaN
# 10           143.000                        NaN                       NaN
#
#    NOMBRE_PAQ_MAS_COMPRADO_MES  PROMEDIO_SALDO_MES  PROMEDIO_SALDO_M1  \
# 0                          NaN                 NaN                NaN
# 4                          NaN            3918.053          12444.077
# 10                         NaN               2.650                NaN
#
#     PROMEDIO_SALDO_M2  ANTIGUEDAD_USUARIO  TOTAL_VALOR_DE_ADELANTA_SALDO  \
# 0                 NaN                 NaN                            NaN
# 4           12279.255            6576.000                          0.000
# 10              2.650            6411.000                          0.000
#
#     ES_SMARTPHONE  CANT_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 0             NaN                                 NaN
# 4           1.000                               2.000
# 10          1.000                                 NaN
#
#     VLR_PAQ_MAS_COMPRADO_MES_ANTERIOR NOMBRE_PAQ_MAS_COMPRADO_MES_ANTERIOR  \
# 0                                 NaN                                  NaN
# 4                           -4000.000            Paquete de datos 200MB+WA
# 10                                NaN                                  NaN
#
#    RAZON1_MA RAZON1_M1 RAZON2_M2 RAZON3_M3 RAZON3_M4  \
# 0        NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN       NaN       NaN       NaN
# 10       NaN       NaN       NaN       NaN       NaN
#
#     DESACTIVACION_PORTACION_M1  DESACTIVACION_PORTACION_M2  \
# 0                            0                           0
# 4                            0                           0
# 10                           0                           0
#
#     DESACTIVACION_PORTACION_M3  DESACTIVACION_PORTACION_M4  \
# 0                            0                           0
# 4                            0                           0
# 10                           0                           0
#
#     ACTIVACION_PORTACION_M1  ACTIVACION_PORTACION_M2  ACTIVACION_PORTACION_M3  \
# 0                         0                        0                        0
# 4                         0                        0                        0
# 10                        0                        0                        0
#
#     ACTIVACION_PORTACION_M4  ACTIGUEDAD_ACT_BSCS  avg_PROM_SEGUNDOS  \
# 0                         0                 6605                NaN
# 4                         0                 6576            395.286
# 10                        0                 6442            497.912
#
#     avg_PROM_DATOS  avg_PROMEDIO_SALDO  slope_PROM_SEGUNDOS  \
# 0              NaN                 NaN                  NaN
# 4      5436421.489            9547.128               41.538
# 10      701667.486               2.650              -88.120
#
#     slope_PROM_SEGUNDOS_cat slope_PROM_SEGUNDOS_cat2
# 0                       NaN                      NaN
# 4                     0.105                 increase
# 10                   -0.177                 decrease

# %%
tabla_1['slope_PROM_DATOS']=tabla_1.apply(lambda x: calcSlopeRow(x,'PROM_DATOS'), axis=1)
tabla_1['slope_PROMEDIO_SALDO']=tabla_1.apply(lambda x: calcSlopeRow(x,'PROMEDIO_SALDO'), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-4b88e0102024> in <module>
#       1 tabla_1['slope_PROM_DATOS']=tabla_1.apply(lambda x: calcSlopeRow(x,'PROM_DATOS'), axis=1)
# ----> 2 tabla_1['slope_PROMEDIO_SALDO']=tabla_1.apply(lambda x: calcSlopeRow(x,'PROMEDIO_SALDO'), axis=1)
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-106-4b88e0102024> in <lambda>(x)
#       1 tabla_1['slope_PROM_DATOS']=tabla_1.apply(lambda x: calcSlopeRow(x,'PROM_DATOS'), axis=1)
# ----> 2 tabla_1['slope_PROMEDIO_SALDO']=tabla_1.apply(lambda x: calcSlopeRow(x,'PROMEDIO_SALDO'), axis=1)
#
# <ipython-input-91-883207cb2ce1> in calcSlopeRow(row, prefix)
#       1 def calcSlopeRow(row,prefix):
#       2     ##data=row.filter(regex='^'+prefix,axis=1).values
# ----> 3     data=list(row.filter(regex='^'+prefix).values)
#       4     ##return calcSlope(data[0])
#       5     if(data.count('Nan')==len(data)):
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4989
#    4990             matcher = re.compile(regex)
# -> 4991             values = labels.map(f)
#    4992             return self.loc(axis=axis)[values]
#    4993         else:
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\indexes\base.py in map(self, mapper, na_action)
#    5115             attributes["dtype"] = self.dtype
#    5116
# -> 5117         return Index(new_values, **attributes)
#    5118
#    5119     # TODO: De-duplicate with map, xref GH#32349
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     356
#     357             if dtype is None:
# --> 358                 new_data, new_dtype = _maybe_cast_data_without_dtype(subarr)
#     359                 if new_dtype is not None:
#     360                     return cls(
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['slope_PROM_DATOS']);
ax.set_xlim(-10000000,10000000)

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['slope_PROMEDIO_SALDO']);
ax.set_xlim(-10000,10000)

# %%
tabla_1['slope_PROM_DATOS_cat']=tabla_1['slope_PROM_DATOS']/tabla_1['avg_PROM_DATOS']
tabla_1['slope_PROMEDIO_SALDO_cat']=tabla_1['slope_PROMEDIO_SALDO']/tabla_1['avg_PROMEDIO_SALDO']

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['slope_PROM_DATOS_cat']);

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,x=tabla_1['slope_PROMEDIO_SALDO_cat']);
#ax.set_xlim(-10000000,10000000)

# %%
tabla_1['slope_PROM_DATOS_cat2']=tabla_1['slope_PROM_DATOS_cat'].apply(categorizacion)
tabla_1['slope_PROMEDIO_SALDO_cat2']=tabla_1['slope_PROMEDIO_SALDO_cat'].apply(categorizacion)

# %%
tabla_1['slope_PROM_DATOS_cat2'].isnull().sum()

# %%
tabla_1['slope_PROM_DATOS_cat2'].value_counts()

# %%
tabla_1['slope_PROMEDIO_SALDO_cat2'].isnull().sum()

# %%
tabla_1['slope_PROMEDIO_SALDO_cat2'].value_counts()

# %% [markdown]
# ####  Recortes

# %%
tabla_1.iloc[[4]]

# %%
prefix='PROM_DATOS'
data=tabla_1.iloc[[4]].filter(regex='^'+prefix,axis=1).values

# %%
data

# %%
len(data[0])

# %%
ind= list(range(0,len(data[0])))
ind

# %%
list(reversed(range(0,len(data[0]))))

# %%
idx=np.isfinite(ind) & np.isfinite(data)

# %%
idx[0]

# %%
ind

# %%
calcSlopeRow(tabla_1.iloc[[4]],'PROM_DATOS')
# Out:
# [[   18618.        5489566.6      21644303.446809      135.
#      29484.4     ]]
# 1
# vals 5
# [ True  True  True  True  True]
# [4, 3, 2, 1, 0]
# 546769.8799999995

# %%
#ordenar para analisis

# %%
calcSlopeRow(tabla_1.iloc[[15]],'PROM_DATOS')

# %%
calcSlopeRow(tabla_1.iloc[[3]],'PROM_DATOS')

# %%
calcSlopeRow(tabla_1.iloc[[11]],'PROM_DATOS')

# %%
len(tabla_1)

# %%
tabla_1['POROUT'].value_counts()
# Out:
# 0    647047
# 1    201274
# Name: POROUT, dtype: int64

# %%
##  Ejercicio 1, SOLO POROUT
tab_1=df[df['POROUT']==1]

# %% [markdown]
# ##  Plan
# * Probar algoritmos de cluster
#  * leer resultados
# * Agregar variables nuevas. promedio y tendencia
# * Tratar variables categoricas
# * validar Binning
# * Probar decision tree

# %%
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
